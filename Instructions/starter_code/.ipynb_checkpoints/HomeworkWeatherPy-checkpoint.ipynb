# %% [markdown]
# # WeatherPy
# ----
# ### Observations:
# * The temperature is higher for those cities that are closer to the equator, which is expected because the equator is the hottest place on earth. Please reference the regression chart. It indicates that there is a corelation between Temperature and Latitude in both the southern and northern hemispheres.
# * As far as the other things go, I don't know how to read a regression scatter plot and no one ever reviews the homework so i'm not sure. Im guessing there is no corelation between latitude and cloudiness, humidity or wind speed because the linear regression line is not exactly linear and data points are scattered.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import scipy.stats as st

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 644

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

lat= []
lon =[]
temp =[]
cityname = []
humidity = []
cloudiness = []
windSpeed = []
country = []
date = []

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="


print(f"Beginning Data Retrieval")
print(f"----------------------------------------")

#set counter
count_city = 0
count_set = 1

for city in cities:
    #Try for error handling
    try:
        response = requests.get(query_url + city).json()
        lat.append(response['coord']['lat'])
        temp.append(response['main']['temp_max'])
        lon.append(response['coord']['lon'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        windSpeed.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        if count_city > 50:
            count_city = 1  
            count_set += 1
            cityname.append(city)
        else:
            count_city += 1
            cityname.append(city)
        print(f"Processing Record {count_city} of Set {count_set} | {city}")    
    
    except:
        print("City not found. Skipping...") 

print("-----------------------------")
print(" "+"Data Retrieval Complete")       
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ----------------------------------------
# Processing Record 1 of Set 1 | hilo
# Processing Record 2 of Set 1 | port elizabeth
# Processing Record 3 of Set 1 | kutum
# Processing Record 4 of Set 1 | mount gambier
# Processing Record 5 of Set 1 | sylva
# Processing Record 6 of Set 1 | martapura
# Processing Record 7 of Set 1 | rawalpindi
# Processing Record 8 of Set 1 | iqaluit
# City not found. Skipping...
# Processing Record 9 of Set 1 | rikitea
# City not found. Skipping...
# Processing Record 10 of Set 1 | biryusinsk
# Processing Record 11 of Set 1 | sinnamary
# Processing Record 12 of Set 1 | albany
# Processing Record 13 of Set 1 | evensk
# Processing Record 14 of Set 1 | tevriz
# Processing Record 15 of Set 1 | punta arenas
# Processing Record 16 of Set 1 | rosarito
# Processing Record 17 of Set 1 | medea
# Processing Record 18 of Set 1 | coos bay
# Processing Record 19 of Set 1 | slave lake
# Processing Record 20 of Set 1 | teya
# Processing Record 21 of Set 1 | pop
# Processing Record 22 of Set 1 | atuona
# Processing Record 23 of Set 1 | new norfolk
# Processing Record 24 of Set 1 | mulchen
# Processing Record 25 of Set 1 | carnarvon
# Processing Record 26 of Set 1 | ushuaia
# Processing Record 27 of Set 1 | henties bay
# City not found. Skipping...
# Processing Record 28 of Set 1 | dharur
# Processing Record 29 of Set 1 | airai
# Processing Record 30 of Set 1 | pasighat
# Processing Record 31 of Set 1 | safaga
# Processing Record 32 of Set 1 | kiomboi
# Processing Record 33 of Set 1 | castro
# Processing Record 34 of Set 1 | katsuura
# City not found. Skipping...
# Processing Record 35 of Set 1 | faanui
# Processing Record 36 of Set 1 | puerto ayora
# Processing Record 37 of Set 1 | ponta do sol
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 38 of Set 1 | jamestown
# Processing Record 39 of Set 1 | avarua
# Processing Record 40 of Set 1 | necochea
# Processing Record 41 of Set 1 | kodiak
# Processing Record 42 of Set 1 | tiksi
# Processing Record 43 of Set 1 | samarai
# Processing Record 44 of Set 1 | busselton
# Processing Record 45 of Set 1 | te anau
# Processing Record 46 of Set 1 | sorong
# Processing Record 47 of Set 1 | cabo san lucas
# Processing Record 48 of Set 1 | bentiu
# Processing Record 49 of Set 1 | bonthe
# Processing Record 50 of Set 1 | mutoko
# Processing Record 51 of Set 1 | mana
# Processing Record 1 of Set 2 | vao
# City not found. Skipping...
# Processing Record 2 of Set 2 | hualmay
# Processing Record 3 of Set 2 | keuruu
# Processing Record 4 of Set 2 | mataura
# Processing Record 5 of Set 2 | edgewater
# Processing Record 6 of Set 2 | ambunti
# Processing Record 7 of Set 2 | barrow
# Processing Record 8 of Set 2 | bambous virieux
# Processing Record 9 of Set 2 | guerrero negro
# Processing Record 10 of Set 2 | durant
# Processing Record 11 of Set 2 | boende
# Processing Record 12 of Set 2 | tudela
# Processing Record 13 of Set 2 | bluff
# Processing Record 14 of Set 2 | butaritari
# Processing Record 15 of Set 2 | cape town
# Processing Record 16 of Set 2 | arraial do cabo
# Processing Record 17 of Set 2 | qingyuan
# Processing Record 18 of Set 2 | qaanaaq
# Processing Record 19 of Set 2 | khatanga
# Processing Record 20 of Set 2 | esperance
# City not found. Skipping...
# Processing Record 21 of Set 2 | vaini
# Processing Record 22 of Set 2 | qasigiannguit
# Processing Record 23 of Set 2 | eureka
# Processing Record 24 of Set 2 | shimonoseki
# Processing Record 25 of Set 2 | kapaa
# City not found. Skipping...
# Processing Record 26 of Set 2 | numan
# Processing Record 27 of Set 2 | laguna
# Processing Record 28 of Set 2 | gotsu
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 29 of Set 2 | zhanakorgan
# Processing Record 30 of Set 2 | manaure
# Processing Record 31 of Set 2 | acapulco
# City not found. Skipping...
# Processing Record 32 of Set 2 | bronnoysund
# Processing Record 33 of Set 2 | sangar
# Processing Record 34 of Set 2 | biak
# Processing Record 35 of Set 2 | srivardhan
# City not found. Skipping...
# Processing Record 36 of Set 2 | pedernales
# Processing Record 37 of Set 2 | hokitika
# Processing Record 38 of Set 2 | bethel
# Processing Record 39 of Set 2 | saint-philippe
# Processing Record 40 of Set 2 | kattivakkam
# Processing Record 41 of Set 2 | upernavik
# Processing Record 42 of Set 2 | kintampo
# City not found. Skipping...
# Processing Record 43 of Set 2 | kapit
# Processing Record 44 of Set 2 | port alfred
# Processing Record 45 of Set 2 | chuy
# Processing Record 46 of Set 2 | cap-aux-meules
# Processing Record 47 of Set 2 | milkovo
# Processing Record 48 of Set 2 | bengkulu
# Processing Record 49 of Set 2 | smithers
# Processing Record 50 of Set 2 | saskylakh
# Processing Record 51 of Set 2 | winsum
# Processing Record 1 of Set 3 | martil
# Processing Record 2 of Set 3 | camapua
# Processing Record 3 of Set 3 | nadym
# Processing Record 4 of Set 3 | inirida
# Processing Record 5 of Set 3 | borova
# Processing Record 6 of Set 3 | tilichiki
# Processing Record 7 of Set 3 | bougouni
# Processing Record 8 of Set 3 | hobart
# Processing Record 9 of Set 3 | bredasdorp
# Processing Record 10 of Set 3 | pacific grove
# Processing Record 11 of Set 3 | nikolskoye
# Processing Record 12 of Set 3 | nouakchott
# Processing Record 13 of Set 3 | shingu
# Processing Record 14 of Set 3 | cockburn town
# Processing Record 15 of Set 3 | turkmenabat
# Processing Record 16 of Set 3 | souillac
# Processing Record 17 of Set 3 | quatre cocos
# Processing Record 18 of Set 3 | russkaya polyana
# Processing Record 19 of Set 3 | beringovskiy
# Processing Record 20 of Set 3 | walvis bay
# Processing Record 21 of Set 3 | tuktoyaktuk
# Processing Record 22 of Set 3 | asfi
# Processing Record 23 of Set 3 | boden
# Processing Record 24 of Set 3 | mahebourg
# Processing Record 25 of Set 3 | salalah
# Processing Record 26 of Set 3 | vila
# Processing Record 27 of Set 3 | ingham
# Processing Record 28 of Set 3 | mehamn
# Processing Record 29 of Set 3 | padang
# Processing Record 30 of Set 3 | guangyuan
# City not found. Skipping...
# Processing Record 31 of Set 3 | vilhena
# Processing Record 32 of Set 3 | corbelia
# Processing Record 33 of Set 3 | guozhen
# Processing Record 34 of Set 3 | hermanus
# Processing Record 35 of Set 3 | lorengau
# Processing Record 36 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 37 of Set 3 | tezu
# Processing Record 38 of Set 3 | kingaroy
# Processing Record 39 of Set 3 | saldanha
# Processing Record 40 of Set 3 | dhidhdhoo
# Processing Record 41 of Set 3 | san patricio
# Processing Record 42 of Set 3 | touros
# Processing Record 43 of Set 3 | kloulklubed
# Processing Record 44 of Set 3 | sorel
# Processing Record 45 of Set 3 | kwinana
# Processing Record 46 of Set 3 | hami
# Processing Record 47 of Set 3 | gizo
# Processing Record 48 of Set 3 | trairi
# City not found. Skipping...
# Processing Record 49 of Set 3 | bilma
# Processing Record 50 of Set 3 | hithadhoo
# Processing Record 51 of Set 3 | bloomsburg
# Processing Record 1 of Set 4 | dikson
# Processing Record 2 of Set 4 | okitipupa
# Processing Record 3 of Set 4 | talnakh
# Processing Record 4 of Set 4 | roebourne
# Processing Record 5 of Set 4 | lagoa
# Processing Record 6 of Set 4 | goderich
# Processing Record 7 of Set 4 | otavi
# Processing Record 8 of Set 4 | fallon
# City not found. Skipping...
# Processing Record 9 of Set 4 | omboue
# Processing Record 10 of Set 4 | kanash
# Processing Record 11 of Set 4 | pacifica
# Processing Record 12 of Set 4 | penzance
# City not found. Skipping...
# Processing Record 13 of Set 4 | ambon
# Processing Record 14 of Set 4 | leh
# Processing Record 15 of Set 4 | ponta delgada
# City not found. Skipping...
# Processing Record 16 of Set 4 | cabras
# Processing Record 17 of Set 4 | husavik
# Processing Record 18 of Set 4 | san ignacio
# Processing Record 19 of Set 4 | pasni
# Processing Record 20 of Set 4 | dunedin
# Processing Record 21 of Set 4 | kaitangata
# Processing Record 22 of Set 4 | tuatapere
# Processing Record 23 of Set 4 | torbay
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 24 of Set 4 | yulara
# Processing Record 25 of Set 4 | zhaoyuan
# Processing Record 26 of Set 4 | tonj
# Processing Record 27 of Set 4 | east london
# Processing Record 28 of Set 4 | ardmore
# Processing Record 29 of Set 4 | namatanai
# Processing Record 30 of Set 4 | santa cruz
# Processing Record 31 of Set 4 | ayagoz
# Processing Record 32 of Set 4 | gorodishche
# Processing Record 33 of Set 4 | cherskiy
# Processing Record 34 of Set 4 | chestermere
# Processing Record 35 of Set 4 | varna
# Processing Record 36 of Set 4 | ulukulevo
# Processing Record 37 of Set 4 | gimli
# Processing Record 38 of Set 4 | samarkand
# Processing Record 39 of Set 4 | adrar
# Processing Record 40 of Set 4 | banda aceh
# Processing Record 41 of Set 4 | gobabis
# Processing Record 42 of Set 4 | valer
# Processing Record 43 of Set 4 | douglas
# Processing Record 44 of Set 4 | yerbogachen
# City not found. Skipping...
# Processing Record 45 of Set 4 | tasiilaq
# Processing Record 46 of Set 4 | port blair
# Processing Record 47 of Set 4 | yellowknife
# Processing Record 48 of Set 4 | jacareacanga
# Processing Record 49 of Set 4 | siilinjarvi
# Processing Record 50 of Set 4 | mackay
# Processing Record 51 of Set 4 | victoria point
# Processing Record 1 of Set 5 | robertsport
# Processing Record 2 of Set 5 | adwa
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 3 of Set 5 | yabrud
# Processing Record 4 of Set 5 | nova olimpia
# Processing Record 5 of Set 5 | thompson
# Processing Record 6 of Set 5 | bathsheba
# Processing Record 7 of Set 5 | churapcha
# Processing Record 8 of Set 5 | sao domingos do maranhao
# Processing Record 9 of Set 5 | alofi
# Processing Record 10 of Set 5 | santiago
# Processing Record 11 of Set 5 | georgetown
# Processing Record 12 of Set 5 | sao felix do xingu
# Processing Record 13 of Set 5 | severo-kurilsk
# Processing Record 14 of Set 5 | sokolovo
# Processing Record 15 of Set 5 | monte patria
# City not found. Skipping...
# Processing Record 16 of Set 5 | okato
# Processing Record 17 of Set 5 | muros
# Processing Record 18 of Set 5 | ambulu
# Processing Record 19 of Set 5 | ribeira grande
# Processing Record 20 of Set 5 | puerto ayacucho
# Processing Record 21 of Set 5 | denpasar
# Processing Record 22 of Set 5 | saint anthony
# Processing Record 23 of Set 5 | geraldton
# Processing Record 24 of Set 5 | fairbanks
# Processing Record 25 of Set 5 | moindou
# Processing Record 26 of Set 5 | grants pass
# Processing Record 27 of Set 5 | chara
# Processing Record 28 of Set 5 | lebu
# Processing Record 29 of Set 5 | hasaki
# City not found. Skipping...
# Processing Record 30 of Set 5 | pevek
# Processing Record 31 of Set 5 | isangel
# Processing Record 32 of Set 5 | mar del plata
# Processing Record 33 of Set 5 | evora
# Processing Record 34 of Set 5 | kazachinskoye
# Processing Record 35 of Set 5 | mahajanga
# Processing Record 36 of Set 5 | le port
# Processing Record 37 of Set 5 | qostanay
# Processing Record 38 of Set 5 | janakpur
# Processing Record 39 of Set 5 | saint george
# Processing Record 40 of Set 5 | shibetsu
# Processing Record 41 of Set 5 | mizdah
# Processing Record 42 of Set 5 | janow lubelski
# Processing Record 43 of Set 5 | taltal
# Processing Record 44 of Set 5 | comodoro rivadavia
# Processing Record 45 of Set 5 | balkanabat
# Processing Record 46 of Set 5 | grivenskaya
# Processing Record 47 of Set 5 | richards bay
# Processing Record 48 of Set 5 | egvekinot
# Processing Record 49 of Set 5 | lisakovsk
# Processing Record 50 of Set 5 | kochevo
# Processing Record 51 of Set 5 | luanda
# Processing Record 1 of Set 6 | kamina
# Processing Record 2 of Set 6 | mount isa
# Processing Record 3 of Set 6 | viedma
# Processing Record 4 of Set 6 | fortuna
# Processing Record 5 of Set 6 | kudahuvadhoo
# Processing Record 6 of Set 6 | grimshaw
# Processing Record 7 of Set 6 | fayaoue
# City not found. Skipping...
# Processing Record 8 of Set 6 | henderson
# Processing Record 9 of Set 6 | venice
# Processing Record 10 of Set 6 | druzhba
# Processing Record 11 of Set 6 | banjar
# Processing Record 12 of Set 6 | jian
# Processing Record 13 of Set 6 | grindavik
# City not found. Skipping...
# Processing Record 14 of Set 6 | nakusp
# Processing Record 15 of Set 6 | abalak
# Processing Record 16 of Set 6 | katherine
# Processing Record 17 of Set 6 | atar
# Processing Record 18 of Set 6 | moa
# Processing Record 19 of Set 6 | komsomolskiy
# Processing Record 20 of Set 6 | morehead
# City not found. Skipping...
# Processing Record 21 of Set 6 | hamilton
# Processing Record 22 of Set 6 | abha
# Processing Record 23 of Set 6 | tiruvallur
# Processing Record 24 of Set 6 | voh
# Processing Record 25 of Set 6 | nanortalik
# Processing Record 26 of Set 6 | phulabani
# Processing Record 27 of Set 6 | kindu
# Processing Record 28 of Set 6 | coahuayana
# Processing Record 29 of Set 6 | cidreira
# Processing Record 30 of Set 6 | luderitz
# City not found. Skipping...
# Processing Record 31 of Set 6 | xining
# Processing Record 32 of Set 6 | zheshart
# Processing Record 33 of Set 6 | coquimbo
# Processing Record 34 of Set 6 | manavalakurichi
# City not found. Skipping...
# Processing Record 35 of Set 6 | flinders
# Processing Record 36 of Set 6 | auki
# Processing Record 37 of Set 6 | canora
# Processing Record 38 of Set 6 | tura
# Processing Record 39 of Set 6 | mandurah
# Processing Record 40 of Set 6 | north bend
# Processing Record 41 of Set 6 | erenhot
# Processing Record 42 of Set 6 | shenjiamen
# Processing Record 43 of Set 6 | soc trang
# Processing Record 44 of Set 6 | sambava
# Processing Record 45 of Set 6 | quelimane
# Processing Record 46 of Set 6 | nantucket
# Processing Record 47 of Set 6 | cherrapunji
# Processing Record 48 of Set 6 | payson
# Processing Record 49 of Set 6 | cururupu
# Processing Record 50 of Set 6 | eenhana
# Processing Record 51 of Set 6 | coaraci
# City not found. Skipping...
# Processing Record 1 of Set 7 | mikuni
# Processing Record 2 of Set 7 | mirabad
# Processing Record 3 of Set 7 | pisco
# Processing Record 4 of Set 7 | carauari
# Processing Record 5 of Set 7 | mo i rana
# Processing Record 6 of Set 7 | satna
# Processing Record 7 of Set 7 | sakakah
# Processing Record 8 of Set 7 | dingle
# Processing Record 9 of Set 7 | pangnirtung
# Processing Record 10 of Set 7 | palmares do sul
# Processing Record 11 of Set 7 | barrhead
# Processing Record 12 of Set 7 | botshabelo
# Processing Record 13 of Set 7 | ruteng
# Processing Record 14 of Set 7 | bouca
# Processing Record 15 of Set 7 | labuhan
# Processing Record 16 of Set 7 | aroeiras
# City not found. Skipping...
# Processing Record 17 of Set 7 | ucluelet
# Processing Record 18 of Set 7 | ancud
# Processing Record 19 of Set 7 | provideniya
# Processing Record 20 of Set 7 | honiara
# Processing Record 21 of Set 7 | iskateley
# Processing Record 22 of Set 7 | malakal
# Processing Record 23 of Set 7 | boa vista
# Processing Record 24 of Set 7 | inta
# Processing Record 25 of Set 7 | ewa beach
# Processing Record 26 of Set 7 | cayenne
# City not found. Skipping...
# Processing Record 27 of Set 7 | umea
# Processing Record 28 of Set 7 | kidal
# Processing Record 29 of Set 7 | deputatskiy
# Processing Record 30 of Set 7 | dali
# Processing Record 31 of Set 7 | port hedland
# Processing Record 32 of Set 7 | valley city
# Processing Record 33 of Set 7 | lavrentiya
# Processing Record 34 of Set 7 | luau
# Processing Record 35 of Set 7 | marshfield
# Processing Record 36 of Set 7 | chokurdakh
# Processing Record 37 of Set 7 | haines junction
# City not found. Skipping...
# Processing Record 38 of Set 7 | neiafu
# Processing Record 39 of Set 7 | grand-santi
# Processing Record 40 of Set 7 | vieux-habitants
# Processing Record 41 of Set 7 | zeya
# Processing Record 42 of Set 7 | longyearbyen
# Processing Record 43 of Set 7 | champua
# Processing Record 44 of Set 7 | tumpat
# Processing Record 45 of Set 7 | yumen
# Processing Record 46 of Set 7 | ishigaki
# Processing Record 47 of Set 7 | codrington
# Processing Record 48 of Set 7 | manta
# Processing Record 49 of Set 7 | college
# City not found. Skipping...
# Processing Record 50 of Set 7 | khuzdar
# Processing Record 51 of Set 7 | bolobo
# Processing Record 1 of Set 8 | victoria
# City not found. Skipping...
# Processing Record 2 of Set 8 | marfino
# Processing Record 3 of Set 8 | mildura
# Processing Record 4 of Set 8 | havelock
# Processing Record 5 of Set 8 | wanning
# City not found. Skipping...
# Processing Record 6 of Set 8 | ahipara
# Processing Record 7 of Set 8 | borgarnes
# Processing Record 8 of Set 8 | dukat
# Processing Record 9 of Set 8 | batagay-alyta
# Processing Record 10 of Set 8 | vinukonda
# Processing Record 11 of Set 8 | palmer
# Processing Record 12 of Set 8 | monrovia
# Processing Record 13 of Set 8 | kulhudhuffushi
# Processing Record 14 of Set 8 | olavarria
# Processing Record 15 of Set 8 | surman
# Processing Record 16 of Set 8 | narsaq
# Processing Record 17 of Set 8 | mwinilunga
# Processing Record 18 of Set 8 | lichinga
# Processing Record 19 of Set 8 | bocana de paiwas
# Processing Record 20 of Set 8 | soubre
# City not found. Skipping...
# Processing Record 21 of Set 8 | marawi
# Processing Record 22 of Set 8 | tual
# Processing Record 23 of Set 8 | dalbandin
# Processing Record 24 of Set 8 | jiblah
# Processing Record 25 of Set 8 | rawson
# Processing Record 26 of Set 8 | marzuq
# Processing Record 27 of Set 8 | stephenville
# Processing Record 28 of Set 8 | kruisfontein
# Processing Record 29 of Set 8 | matipo
# Processing Record 30 of Set 8 | sabang
# Processing Record 31 of Set 8 | westport
# Processing Record 32 of Set 8 | nokaneng
# Processing Record 33 of Set 8 | aykhal
# Processing Record 34 of Set 8 | srednekolymsk
# Processing Record 35 of Set 8 | ylojarvi
# Processing Record 36 of Set 8 | prabumulih
# Processing Record 37 of Set 8 | hay river
# Processing Record 38 of Set 8 | naze
# Processing Record 39 of Set 8 | constitucion
# Processing Record 40 of Set 8 | bhatkal
# Processing Record 41 of Set 8 | lompoc
# Processing Record 42 of Set 8 | dalmatovo
# Processing Record 43 of Set 8 | locri
# Processing Record 44 of Set 8 | mongomo
# Processing Record 45 of Set 8 | port lincoln
# Processing Record 46 of Set 8 | zawiercie
# Processing Record 47 of Set 8 | coracora
# Processing Record 48 of Set 8 | grahamstown
# Processing Record 49 of Set 8 | karratha
# Processing Record 50 of Set 8 | preobrazheniye
# Processing Record 51 of Set 8 | petersburg
# Processing Record 1 of Set 9 | malinyi
# Processing Record 2 of Set 9 | hefei
# Processing Record 3 of Set 9 | issia
# Processing Record 4 of Set 9 | kizukuri
# Processing Record 5 of Set 9 | japura
# Processing Record 6 of Set 9 | santa maria
# Processing Record 7 of Set 9 | rocha
# Processing Record 8 of Set 9 | ugoofaaru
# Processing Record 9 of Set 9 | jaciara
# Processing Record 10 of Set 9 | zwedru
# Processing Record 11 of Set 9 | hearst
# Processing Record 12 of Set 9 | sistranda
# Processing Record 13 of Set 9 | pangody
# Processing Record 14 of Set 9 | palau
# Processing Record 15 of Set 9 | hofn
# Processing Record 16 of Set 9 | la ciotat
# Processing Record 17 of Set 9 | megion
# City not found. Skipping...
# Processing Record 18 of Set 9 | hatillo
# Processing Record 19 of Set 9 | sabya
# Processing Record 20 of Set 9 | qingdao
# Processing Record 21 of Set 9 | saint-francois
# Processing Record 22 of Set 9 | tabas
# Processing Record 23 of Set 9 | bagdarin
# Processing Record 24 of Set 9 | sorland
# Processing Record 25 of Set 9 | verkh-usugli
# Processing Record 26 of Set 9 | mayo
# Processing Record 27 of Set 9 | oyama
# Processing Record 28 of Set 9 | murray bridge
# Processing Record 29 of Set 9 | iralaya
# Processing Record 30 of Set 9 | huntington
# Processing Record 31 of Set 9 | shaunavon
# Processing Record 32 of Set 9 | kunyang
# Processing Record 33 of Set 9 | ayotzintepec
# Processing Record 34 of Set 9 | kaohsiung
# Processing Record 35 of Set 9 | tessalit
# Processing Record 36 of Set 9 | rio claro
# Processing Record 37 of Set 9 | mogocha
# City not found. Skipping...
# Processing Record 38 of Set 9 | half moon bay
# Processing Record 39 of Set 9 | leningradskiy
# Processing Record 40 of Set 9 | zhezkazgan
# Processing Record 41 of Set 9 | barcelos
# Processing Record 42 of Set 9 | clyde river
# Processing Record 43 of Set 9 | alice springs
# City not found. Skipping...
# Processing Record 44 of Set 9 | kavaratti
# Processing Record 45 of Set 9 | paramonga
# Processing Record 46 of Set 9 | sitka
# Processing Record 47 of Set 9 | najran
# Processing Record 48 of Set 9 | ogdensburg
# Processing Record 49 of Set 9 | vila velha
# Processing Record 50 of Set 9 | xinqing
# Processing Record 51 of Set 9 | champaign
# Processing Record 1 of Set 10 | sturgis
# City not found. Skipping...
# Processing Record 2 of Set 10 | bria
# Processing Record 3 of Set 10 | mexicali
# Processing Record 4 of Set 10 | galveston
# Processing Record 5 of Set 10 | arenillas
# City not found. Skipping...
# Processing Record 6 of Set 10 | san cristobal
# Processing Record 7 of Set 10 | tsabong
# Processing Record 8 of Set 10 | brighton
# Processing Record 9 of Set 10 | mazagao
# Processing Record 10 of Set 10 | faya
# Processing Record 11 of Set 10 | dubbo
# Processing Record 12 of Set 10 | gwadar
# Processing Record 13 of Set 10 | aketi
# Processing Record 14 of Set 10 | roald
# Processing Record 15 of Set 10 | northport
# Processing Record 16 of Set 10 | berdigestyakh
# Processing Record 17 of Set 10 | portland
# Processing Record 18 of Set 10 | avera
# Processing Record 19 of Set 10 | mareeba
# Processing Record 20 of Set 10 | vostok
# City not found. Skipping...
# Processing Record 21 of Set 10 | chernyshevskiy
# Processing Record 22 of Set 10 | craig
# Processing Record 23 of Set 10 | birjand
# Processing Record 24 of Set 10 | sisimiut
# Processing Record 25 of Set 10 | sinjar
# Processing Record 26 of Set 10 | nuuk
# Processing Record 27 of Set 10 | tahara
# Processing Record 28 of Set 10 | aklavik
# Processing Record 29 of Set 10 | vardo
# City not found. Skipping...
# Processing Record 30 of Set 10 | akureyri
# Processing Record 31 of Set 10 | lasa
# Processing Record 32 of Set 10 | kavieng
# City not found. Skipping...
# Processing Record 33 of Set 10 | klaksvik
# Processing Record 34 of Set 10 | opuwo
# Processing Record 35 of Set 10 | nome
# Processing Record 36 of Set 10 | sao joao da barra
# Processing Record 37 of Set 10 | broken hill
# Processing Record 38 of Set 10 | meulaboh
# Processing Record 39 of Set 10 | sawakin
# Processing Record 40 of Set 10 | wukari
# City not found. Skipping...
# Processing Record 41 of Set 10 | baculin
# Processing Record 42 of Set 10 | naryan-mar
# Processing Record 43 of Set 10 | poindimie
# Processing Record 44 of Set 10 | champerico
# Processing Record 45 of Set 10 | pemangkat
# Processing Record 46 of Set 10 | nyurba
# Processing Record 47 of Set 10 | olafsvik
# Processing Record 48 of Set 10 | tingo maria
# Processing Record 49 of Set 10 | orda
# Processing Record 50 of Set 10 | bubaque
# Processing Record 51 of Set 10 | norman wells
# Processing Record 1 of Set 11 | samfya
# Processing Record 2 of Set 11 | darhan
# Processing Record 3 of Set 11 | tondi
# Processing Record 4 of Set 11 | yazd
# Processing Record 5 of Set 11 | alamogordo
# Processing Record 6 of Set 11 | yakeshi
# Processing Record 7 of Set 11 | pemba
# Processing Record 8 of Set 11 | barstow
# Processing Record 9 of Set 11 | moen
# Processing Record 10 of Set 11 | sao filipe
# Processing Record 11 of Set 11 | vanimo
# Processing Record 12 of Set 11 | brazzaville
# Processing Record 13 of Set 11 | carberry
# Processing Record 14 of Set 11 | olinala
# Processing Record 15 of Set 11 | nacala
# Processing Record 16 of Set 11 | san angelo
# Processing Record 17 of Set 11 | mao
# Processing Record 18 of Set 11 | killarney
# Processing Record 19 of Set 11 | lawrenceburg
# Processing Record 20 of Set 11 | homer
# Processing Record 21 of Set 11 | nicoya
# Processing Record 22 of Set 11 | kabalo
# City not found. Skipping...
# Processing Record 23 of Set 11 | hue
# Processing Record 24 of Set 11 | haimen
# Processing Record 25 of Set 11 | sikandra
# Processing Record 26 of Set 11 | kyaka
# Processing Record 27 of Set 11 | leninskiy
# Processing Record 28 of Set 11 | northam
# Processing Record 29 of Set 11 | palanpur
# City not found. Skipping...
# Processing Record 30 of Set 11 | carndonagh
# Processing Record 31 of Set 11 | kisangani
# Processing Record 32 of Set 11 | latung
# Processing Record 33 of Set 11 | corrales
# Processing Record 34 of Set 11 | olinda
# Processing Record 35 of Set 11 | bud
# Processing Record 36 of Set 11 | garden city
# Processing Record 37 of Set 11 | botwood
# Processing Record 38 of Set 11 | san policarpo
# Processing Record 39 of Set 11 | north battleford
# Processing Record 40 of Set 11 | lodja
# Processing Record 41 of Set 11 | manzhouli
# Processing Record 42 of Set 11 | waddan
# Processing Record 43 of Set 11 | kariapatti
# Processing Record 44 of Set 11 | port hardy
# Processing Record 45 of Set 11 | santa rosa
# Processing Record 46 of Set 11 | bosaso
# Processing Record 47 of Set 11 | tolyatti
# Processing Record 48 of Set 11 | luba
# Processing Record 49 of Set 11 | hambantota
# Processing Record 50 of Set 11 | piacabucu
# Processing Record 51 of Set 11 | dembi dolo
# Processing Record 1 of Set 12 | broome
# Processing Record 2 of Set 12 | sterling
# Processing Record 3 of Set 12 | morros
# Processing Record 4 of Set 12 | asau
# Processing Record 5 of Set 12 | saint-joseph
# Processing Record 6 of Set 12 | axim
# Processing Record 7 of Set 12 | camacha
# Processing Record 8 of Set 12 | tazovskiy
# City not found. Skipping...
# Processing Record 9 of Set 12 | manicore
# Processing Record 10 of Set 12 | poddorye
# Processing Record 11 of Set 12 | djibo
# Processing Record 12 of Set 12 | pemberton
# Processing Record 13 of Set 12 | planeta rica
# Processing Record 14 of Set 12 | gat
# City not found. Skipping...
# Processing Record 15 of Set 12 | boquira
# Processing Record 16 of Set 12 | brigantine
# Processing Record 17 of Set 12 | katyuzhanka
# Processing Record 18 of Set 12 | zhigansk
# Processing Record 19 of Set 12 | khazar
# Processing Record 20 of Set 12 | praia
# Processing Record 21 of Set 12 | maracacume
# Processing Record 22 of Set 12 | manggar
# Processing Record 23 of Set 12 | mayya
# Processing Record 24 of Set 12 | carutapera
# Processing Record 25 of Set 12 | jiuquan
# Processing Record 26 of Set 12 | ust-kachka
# Processing Record 27 of Set 12 | ravar
# City not found. Skipping...
# Processing Record 28 of Set 12 | los llanos de aridane
# Processing Record 29 of Set 12 | celestun
# -----------------------------
#  Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Convert Raw Data to DataFrame
#Export the city data into csv
city_dict = {
    "City": cityname,
    "Cloudiness":cloudiness, 
    "Country":country,
    "Date":date, 
    "Humidity": humidity,
    "Lat":lat, 
    "Lng":lon, 
    "Max Temp": temp,
    "Wind Speed":windSpeed
}
city_dict
# Out:
# {'City': ['hilo',
#   'port elizabeth',
#   'kutum',
#   'mount gambier',
#   'sylva',
#   'martapura',
#   'rawalpindi',
#   'iqaluit',
#   'rikitea',
#   'biryusinsk',
#   'sinnamary',
#   'albany',
#   'evensk',
#   'tevriz',
#   'punta arenas',
#   'rosarito',
#   'medea',
#   'coos bay',
#   'slave lake',
#   'teya',
#   'pop',
#   'atuona',
#   'new norfolk',
#   'mulchen',
#   'carnarvon',
#   'ushuaia',
#   'henties bay',
#   'dharur',
#   'airai',
#   'pasighat',
#   'safaga',
#   'kiomboi',
#   'castro',
#   'katsuura',
#   'faanui',
#   'puerto ayora',
#   'ponta do sol',
#   'jamestown',
#   'avarua',
#   'necochea',
#   'kodiak',
#   'tiksi',
#   'samarai',
#   'busselton',
#   'te anau',
#   'sorong',
#   'cabo san lucas',
#   'bentiu',
#   'bonthe',
#   'mutoko',
#   'mana',
#   'vao',
#   'hualmay',
#   'keuruu',
#   'mataura',
#   'edgewater',
#   'ambunti',
#   'barrow',
#   'bambous virieux',
#   'guerrero negro',
#   'durant',
#   'boende',
#   'tudela',
#   'bluff',
#   'butaritari',
#   'cape town',
#   'arraial do cabo',
#   'qingyuan',
#   'qaanaaq',
#   'khatanga',
#   'esperance',
#   'vaini',
#   'qasigiannguit',
#   'eureka',
#   'shimonoseki',
#   'kapaa',
#   'numan',
#   'laguna',
#   'gotsu',
#   'zhanakorgan',
#   'manaure',
#   'acapulco',
#   'bronnoysund',
#   'sangar',
#   'biak',
#   'srivardhan',
#   'pedernales',
#   'hokitika',
#   'bethel',
#   'saint-philippe',
#   'kattivakkam',
#   'upernavik',
#   'kintampo',
#   'kapit',
#   'port alfred',
#   'chuy',
#   'cap-aux-meules',
#   'milkovo',
#   'bengkulu',
#   'smithers',
#   'saskylakh',
#   'winsum',
#   'martil',
#   'camapua',
#   'nadym',
#   'inirida',
#   'borova',
#   'tilichiki',
#   'bougouni',
#   'hobart',
#   'bredasdorp',
#   'pacific grove',
#   'nikolskoye',
#   'nouakchott',
#   'shingu',
#   'cockburn town',
#   'turkmenabat',
#   'souillac',
#   'quatre cocos',
#   'russkaya polyana',
#   'beringovskiy',
#   'walvis bay',
#   'tuktoyaktuk',
#   'asfi',
#   'boden',
#   'mahebourg',
#   'salalah',
#   'vila',
#   'ingham',
#   'mehamn',
#   'padang',
#   'guangyuan',
#   'vilhena',
#   'corbelia',
#   'guozhen',
#   'hermanus',
#   'lorengau',
#   'petropavlovsk-kamchatskiy',
#   'tezu',
#   'kingaroy',
#   'saldanha',
#   'dhidhdhoo',
#   'san patricio',
#   'touros',
#   'kloulklubed',
#   'sorel',
#   'kwinana',
#   'hami',
#   'gizo',
#   'trairi',
#   'bilma',
#   'hithadhoo',
#   'bloomsburg',
#   'dikson',
#   'okitipupa',
#   'talnakh',
#   'roebourne',
#   'lagoa',
#   'goderich',
#   'otavi',
#   'fallon',
#   'omboue',
#   'kanash',
#   'pacifica',
#   'penzance',
#   'ambon',
#   'leh',
#   'ponta delgada',
#   'cabras',
#   'husavik',
#   'san ignacio',
#   'pasni',
#   'dunedin',
#   'kaitangata',
#   'tuatapere',
#   'torbay',
#   'yulara',
#   'zhaoyuan',
#   'tonj',
#   'east london',
#   'ardmore',
#   'namatanai',
#   'santa cruz',
#   'ayagoz',
#   'gorodishche',
#   'cherskiy',
#   'chestermere',
#   'varna',
#   'ulukulevo',
#   'gimli',
#   'samarkand',
#   'adrar',
#   'banda aceh',
#   'gobabis',
#   'valer',
#   'douglas',
#   'yerbogachen',
#   'tasiilaq',
#   'port blair',
#   'yellowknife',
#   'jacareacanga',
#   'siilinjarvi',
#   'mackay',
#   'victoria point',
#   'robertsport',
#   'adwa',
#   'yabrud',
#   'nova olimpia',
#   'thompson',
#   'bathsheba',
#   'churapcha',
#   'sao domingos do maranhao',
#   'alofi',
#   'santiago',
#   'georgetown',
#   'sao felix do xingu',
#   'severo-kurilsk',
#   'sokolovo',
#   'monte patria',
#   'okato',
#   'muros',
#   'ambulu',
#   'ribeira grande',
#   'puerto ayacucho',
#   'denpasar',
#   'saint anthony',
#   'geraldton',
#   'fairbanks',
#   'moindou',
#   'grants pass',
#   'chara',
#   'lebu',
#   'hasaki',
#   'pevek',
#   'isangel',
#   'mar del plata',
#   'evora',
#   'kazachinskoye',
#   'mahajanga',
#   'le port',
#   'qostanay',
#   'janakpur',
#   'saint george',
#   'shibetsu',
#   'mizdah',
#   'janow lubelski',
#   'taltal',
#   'comodoro rivadavia',
#   'balkanabat',
#   'grivenskaya',
#   'richards bay',
#   'egvekinot',
#   'lisakovsk',
#   'kochevo',
#   'luanda',
#   'kamina',
#   'mount isa',
#   'viedma',
#   'fortuna',
#   'kudahuvadhoo',
#   'grimshaw',
#   'fayaoue',
#   'henderson',
#   'venice',
#   'druzhba',
#   'banjar',
#   'jian',
#   'grindavik',
#   'nakusp',
#   'abalak',
#   'katherine',
#   'atar',
#   'moa',
#   'komsomolskiy',
#   'morehead',
#   'hamilton',
#   'abha',
#   'tiruvallur',
#   'voh',
#   'nanortalik',
#   'phulabani',
#   'kindu',
#   'coahuayana',
#   'cidreira',
#   'luderitz',
#   'xining',
#   'zheshart',
#   'coquimbo',
#   'manavalakurichi',
#   'flinders',
#   'auki',
#   'canora',
#   'tura',
#   'mandurah',
#   'north bend',
#   'erenhot',
#   'shenjiamen',
#   'soc trang',
#   'sambava',
#   'quelimane',
#   'nantucket',
#   'cherrapunji',
#   'payson',
#   'cururupu',
#   'eenhana',
#   'coaraci',
#   'mikuni',
#   'mirabad',
#   'pisco',
#   'carauari',
#   'mo i rana',
#   'satna',
#   'sakakah',
#   'dingle',
#   'pangnirtung',
#   'palmares do sul',
#   'barrhead',
#   'botshabelo',
#   'ruteng',
#   'bouca',
#   'labuhan',
#   'aroeiras',
#   'ucluelet',
#   'ancud',
#   'provideniya',
#   'honiara',
#   'iskateley',
#   'malakal',
#   'boa vista',
#   'inta',
#   'ewa beach',
#   'cayenne',
#   'umea',
#   'kidal',
#   'deputatskiy',
#   'dali',
#   'port hedland',
#   'valley city',
#   'lavrentiya',
#   'luau',
#   'marshfield',
#   'chokurdakh',
#   'haines junction',
#   'neiafu',
#   'grand-santi',
#   'vieux-habitants',
#   'zeya',
#   'longyearbyen',
#   'champua',
#   'tumpat',
#   'yumen',
#   'ishigaki',
#   'codrington',
#   'manta',
#   'college',
#   'khuzdar',
#   'bolobo',
#   'victoria',
#   'marfino',
#   'mildura',
#   'havelock',
#   'wanning',
#   'ahipara',
#   'borgarnes',
#   'dukat',
#   'batagay-alyta',
#   'vinukonda',
#   'palmer',
#   'monrovia',
#   'kulhudhuffushi',
#   'olavarria',
#   'surman',
#   'narsaq',
#   'mwinilunga',
#   'lichinga',
#   'bocana de paiwas',
#   'soubre',
#   'marawi',
#   'tual',
#   'dalbandin',
#   'jiblah',
#   'rawson',
#   'marzuq',
#   'stephenville',
#   'kruisfontein',
#   'matipo',
#   'sabang',
#   'westport',
#   'nokaneng',
#   'aykhal',
#   'srednekolymsk',
#   'ylojarvi',
#   'prabumulih',
#   'hay river',
#   'naze',
#   'constitucion',
#   'bhatkal',
#   'lompoc',
#   'dalmatovo',
#   'locri',
#   'mongomo',
#   'port lincoln',
#   'zawiercie',
#   'coracora',
#   'grahamstown',
#   'karratha',
#   'preobrazheniye',
#   'petersburg',
#   'malinyi',
#   'hefei',
#   'issia',
#   'kizukuri',
#   'japura',
#   'santa maria',
#   'rocha',
#   'ugoofaaru',
#   'jaciara',
#   'zwedru',
#   'hearst',
#   'sistranda',
#   'pangody',
#   'palau',
#   'hofn',
#   'la ciotat',
#   'megion',
#   'hatillo',
#   'sabya',
#   'qingdao',
#   'saint-francois',
#   'tabas',
#   'bagdarin',
#   'sorland',
#   'verkh-usugli',
#   'mayo',
#   'oyama',
#   'murray bridge',
#   'iralaya',
#   'huntington',
#   'shaunavon',
#   'kunyang',
#   'ayotzintepec',
#   'kaohsiung',
#   'tessalit',
#   'rio claro',
#   'mogocha',
#   'half moon bay',
#   'leningradskiy',
#   'zhezkazgan',
#   'barcelos',
#   'clyde river',
#   'alice springs',
#   'kavaratti',
#   'paramonga',
#   'sitka',
#   'najran',
#   'ogdensburg',
#   'vila velha',
#   'xinqing',
#   'champaign',
#   'sturgis',
#   'bria',
#   'mexicali',
#   'galveston',
#   'arenillas',
#   'san cristobal',
#   'tsabong',
#   'brighton',
#   'mazagao',
#   'faya',
#   'dubbo',
#   'gwadar',
#   'aketi',
#   'roald',
#   'northport',
#   'berdigestyakh',
#   'portland',
#   'avera',
#   'mareeba',
#   'vostok',
#   'chernyshevskiy',
#   'craig',
#   'birjand',
#   'sisimiut',
#   'sinjar',
#   'nuuk',
#   'tahara',
#   'aklavik',
#   'vardo',
#   'akureyri',
#   'lasa',
#   'kavieng',
#   'klaksvik',
#   'opuwo',
#   'nome',
#   'sao joao da barra',
#   'broken hill',
#   'meulaboh',
#   'sawakin',
#   'wukari',
#   'baculin',
#   'naryan-mar',
#   'poindimie',
#   'champerico',
#   'pemangkat',
#   'nyurba',
#   'olafsvik',
#   'tingo maria',
#   'orda',
#   'bubaque',
#   'norman wells',
#   'samfya',
#   'darhan',
#   'tondi',
#   'yazd',
#   'alamogordo',
#   'yakeshi',
#   'pemba',
#   'barstow',
#   'moen',
#   'sao filipe',
#   'vanimo',
#   'brazzaville',
#   'carberry',
#   'olinala',
#   'nacala',
#   'san angelo',
#   'mao',
#   'killarney',
#   'lawrenceburg',
#   'homer',
#   'nicoya',
#   'kabalo',
#   'hue',
#   'haimen',
#   'sikandra',
#   'kyaka',
#   'leninskiy',
#   'northam',
#   'palanpur',
#   'carndonagh',
#   'kisangani',
#   'latung',
#   'corrales',
#   'olinda',
#   'bud',
#   'garden city',
#   'botwood',
#   'san policarpo',
#   'north battleford',
#   'lodja',
#   'manzhouli',
#   'waddan',
#   'kariapatti',
#   'port hardy',
#   'santa rosa',
#   'bosaso',
#   'tolyatti',
#   'luba',
#   'hambantota',
#   'piacabucu',
#   'dembi dolo',
#   'broome',
#   'sterling',
#   'morros',
#   'asau',
#   'saint-joseph',
#   'axim',
#   'camacha',
#   'tazovskiy',
#   'manicore',
#   'poddorye',
#   'djibo',
#   'pemberton',
#   'planeta rica',
#   'gat',
#   'boquira',
#   'brigantine',
#   'katyuzhanka',
#   'zhigansk',
#   'khazar',
#   'praia',
#   'maracacume',
#   'manggar',
#   'mayya',
#   'carutapera',
#   'jiuquan',
#   'ust-kachka',
#   'ravar',
#   'los llanos de aridane',
#   'celestun'],
#  'Cloudiness': [1,
#   0,
#   64,
#   90,
#   99,
#   83,
#   96,
#   90,
#   58,
#   98,
#   78,
#   8,
#   0,
#   9,
#   9,
#   5,
#   0,
#   90,
#   90,
#   100,
#   0,
#   2,
#   100,
#   98,
#   0,
#   28,
#   0,
#   100,
#   67,
#   100,
#   0,
#   60,
#   6,
#   75,
#   54,
#   99,
#   20,
#   1,
#   70,
#   100,
#   1,
#   98,
#   80,
#   3,
#   46,
#   22,
#   20,
#   100,
#   100,
#   28,
#   92,
#   43,
#   63,
#   20,
#   95,
#   75,
#   30,
#   90,
#   75,
#   7,
#   40,
#   37,
#   74,
#   99,
#   100,
#   0,
#   20,
#   19,
#   54,
#   29,
#   0,
#   20,
#   98,
#   51,
#   75,
#   20,
#   89,
#   1,
#   75,
#   1,
#   54,
#   75,
#   38,
#   100,
#   53,
#   100,
#   94,
#   88,
#   1,
#   90,
#   40,
#   99,
#   41,
#   57,
#   0,
#   100,
#   20,
#   98,
#   91,
#   40,
#   100,
#   5,
#   40,
#   0,
#   0,
#   93,
#   0,
#   0,
#   51,
#   75,
#   0,
#   75,
#   40,
#   43,
#   75,
#   4,
#   0,
#   75,
#   75,
#   6,
#   0,
#   0,
#   90,
#   0,
#   25,
#   75,
#   90,
#   59,
#   1,
#   100,
#   40,
#   93,
#   0,
#   56,
#   97,
#   0,
#   48,
#   40,
#   100,
#   40,
#   0,
#   100,
#   40,
#   33,
#   90,
#   24,
#   0,
#   14,
#   42,
#   27,
#   1,
#   87,
#   75,
#   100,
#   100,
#   75,
#   0,
#   0,
#   17,
#   0,
#   40,
#   59,
#   75,
#   40,
#   95,
#   75,
#   65,
#   40,
#   0,
#   90,
#   20,
#   100,
#   57,
#   51,
#   85,
#   20,
#   12,
#   95,
#   93,
#   0,
#   1,
#   27,
#   14,
#   29,
#   3,
#   65,
#   75,
#   0,
#   75,
#   58,
#   0,
#   78,
#   100,
#   0,
#   85,
#   75,
#   98,
#   97,
#   99,
#   40,
#   18,
#   99,
#   75,
#   100,
#   100,
#   99,
#   0,
#   0,
#   75,
#   20,
#   100,
#   9,
#   50,
#   75,
#   20,
#   16,
#   23,
#   44,
#   91,
#   97,
#   0,
#   43,
#   22,
#   40,
#   40,
#   20,
#   0,
#   90,
#   90,
#   1,
#   10,
#   85,
#   75,
#   100,
#   55,
#   90,
#   0,
#   91,
#   4,
#   90,
#   77,
#   86,
#   1,
#   75,
#   0,
#   0,
#   83,
#   40,
#   0,
#   0,
#   0,
#   79,
#   100,
#   50,
#   4,
#   4,
#   0,
#   100,
#   90,
#   95,
#   75,
#   53,
#   1,
#   1,
#   38,
#   40,
#   46,
#   75,
#   58,
#   0,
#   47,
#   40,
#   57,
#   0,
#   75,
#   75,
#   86,
#   40,
#   3,
#   96,
#   100,
#   2,
#   75,
#   95,
#   0,
#   4,
#   67,
#   75,
#   40,
#   43,
#   60,
#   90,
#   99,
#   0,
#   90,
#   0,
#   75,
#   13,
#   23,
#   24,
#   1,
#   100,
#   75,
#   39,
#   0,
#   0,
#   75,
#   0,
#   40,
#   41,
#   62,
#   98,
#   6,
#   100,
#   100,
#   99,
#   100,
#   0,
#   51,
#   64,
#   92,
#   24,
#   90,
#   100,
#   40,
#   75,
#   0,
#   100,
#   100,
#   0,
#   75,
#   20,
#   31,
#   100,
#   67,
#   100,
#   0,
#   20,
#   43,
#   0,
#   90,
#   100,
#   52,
#   20,
#   87,
#   75,
#   72,
#   75,
#   100,
#   20,
#   79,
#   40,
#   99,
#   75,
#   75,
#   25,
#   2,
#   2,
#   20,
#   90,
#   1,
#   47,
#   78,
#   90,
#   0,
#   18,
#   100,
#   20,
#   75,
#   100,
#   99,
#   0,
#   58,
#   0,
#   13,
#   100,
#   73,
#   100,
#   21,
#   0,
#   98,
#   100,
#   100,
#   1,
#   0,
#   12,
#   100,
#   1,
#   0,
#   90,
#   13,
#   90,
#   80,
#   75,
#   20,
#   98,
#   95,
#   72,
#   45,
#   40,
#   26,
#   35,
#   75,
#   0,
#   0,
#   0,
#   91,
#   1,
#   99,
#   100,
#   54,
#   75,
#   42,
#   100,
#   100,
#   100,
#   0,
#   97,
#   100,
#   40,
#   0,
#   90,
#   100,
#   5,
#   12,
#   45,
#   68,
#   100,
#   100,
#   0,
#   3,
#   78,
#   1,
#   1,
#   75,
#   46,
#   75,
#   1,
#   93,
#   94,
#   95,
#   40,
#   74,
#   0,
#   22,
#   90,
#   99,
#   36,
#   22,
#   90,
#   0,
#   100,
#   76,
#   90,
#   40,
#   1,
#   20,
#   51,
#   90,
#   40,
#   64,
#   5,
#   1,
#   44,
#   75,
#   0,
#   15,
#   75,
#   92,
#   73,
#   100,
#   97,
#   100,
#   1,
#   18,
#   1,
#   75,
#   75,
#   0,
#   96,
#   1,
#   0,
#   100,
#   0,
#   37,
#   75,
#   90,
#   84,
#   90,
#   40,
#   4,
#   3,
#   0,
#   75,
#   0,
#   40,
#   100,
#   85,
#   87,
#   57,
#   0,
#   1,
#   90,
#   34,
#   8,
#   100,
#   9,
#   85,
#   100,
#   90,
#   1,
#   70,
#   100,
#   0,
#   1,
#   4,
#   75,
#   1,
#   100,
#   62,
#   39,
#   0,
#   75,
#   83,
#   0,
#   40,
#   0,
#   77,
#   1,
#   1,
#   75,
#   10,
#   20,
#   40,
#   99,
#   43,
#   44,
#   38,
#   43,
#   100,
#   99,
#   99,
#   40,
#   40,
#   1,
#   90,
#   0,
#   71,
#   75,
#   0,
#   42,
#   0,
#   20,
#   75,
#   97,
#   27,
#   37,
#   40,
#   100,
#   1,
#   100,
#   90,
#   90,
#   32,
#   0,
#   90,
#   94,
#   75,
#   39,
#   1,
#   98,
#   32,
#   75,
#   75,
#   0,
#   44,
#   1,
#   0,
#   100,
#   100,
#   31,
#   98,
#   57,
#   99,
#   67,
#   62,
#   98,
#   0,
#   75,
#   11],
#  'Country': ['US',
#   'ZA',
#   'SD',
#   'AU',
#   'RU',
#   'ID',
#   'PK',
#   'CA',
#   'PF',
#   'RU',
#   'GF',
#   'US',
#   'RU',
#   'RU',
#   'CL',
#   'MX',
#   'DZ',
#   'US',
#   'CA',
#   'RU',
#   'UZ',
#   'PF',
#   'AU',
#   'CL',
#   'AU',
#   'AR',
#   'NA',
#   'IN',
#   'TL',
#   'IN',
#   'EG',
#   'TZ',
#   'BR',
#   'JP',
#   'PF',
#   'EC',
#   'PT',
#   'US',
#   'CK',
#   'AR',
#   'US',
#   'RU',
#   'PG',
#   'AU',
#   'NZ',
#   'ID',
#   'MX',
#   'SS',
#   'SL',
#   'ZW',
#   'GF',
#   'NC',
#   'PE',
#   'FI',
#   'NZ',
#   'US',
#   'PG',
#   'US',
#   'MU',
#   'MX',
#   'US',
#   'CD',
#   'ES',
#   'NZ',
#   'KI',
#   'ZA',
#   'BR',
#   'CN',
#   'GL',
#   'RU',
#   'AU',
#   'TO',
#   'GL',
#   'US',
#   'JP',
#   'US',
#   'NG',
#   'US',
#   'JP',
#   'KZ',
#   'CO',
#   'MX',
#   'NO',
#   'RU',
#   'ID',
#   'IN',
#   'DO',
#   'NZ',
#   'US',
#   'RE',
#   'IN',
#   'GL',
#   'GH',
#   'MY',
#   'ZA',
#   'UY',
#   'CA',
#   'RU',
#   'ID',
#   'CA',
#   'RU',
#   'NL',
#   'MA',
#   'BR',
#   'RU',
#   'CO',
#   'UA',
#   'RU',
#   'ML',
#   'AU',
#   'ZA',
#   'US',
#   'RU',
#   'MR',
#   'JP',
#   'TC',
#   'TM',
#   'MU',
#   'MU',
#   'UA',
#   'RU',
#   'NA',
#   'CA',
#   'MA',
#   'SE',
#   'MU',
#   'OM',
#   'PT',
#   'US',
#   'NO',
#   'ID',
#   'CN',
#   'BR',
#   'BR',
#   'CN',
#   'ZA',
#   'PG',
#   'RU',
#   'IN',
#   'AU',
#   'ZA',
#   'MV',
#   'MX',
#   'BR',
#   'PW',
#   'CA',
#   'AU',
#   'CN',
#   'SB',
#   'BR',
#   'NE',
#   'MV',
#   'US',
#   'RU',
#   'NG',
#   'RU',
#   'AU',
#   'PT',
#   'CA',
#   'NA',
#   'US',
#   'GA',
#   'RU',
#   'US',
#   'GB',
#   'ID',
#   'IN',
#   'PT',
#   'IT',
#   'IS',
#   'BZ',
#   'PK',
#   'NZ',
#   'NZ',
#   'NZ',
#   'CA',
#   'AU',
#   'CN',
#   'SS',
#   'ZA',
#   'US',
#   'PG',
#   'BO',
#   'KZ',
#   'RU',
#   'RU',
#   'CA',
#   'BG',
#   'RU',
#   'CA',
#   'UZ',
#   'MR',
#   'ID',
#   'NA',
#   'NO',
#   'US',
#   'RU',
#   'GL',
#   'IN',
#   'CA',
#   'BR',
#   'FI',
#   'AU',
#   'AU',
#   'LR',
#   'ET',
#   'SY',
#   'BR',
#   'CA',
#   'BB',
#   'RU',
#   'BR',
#   'NU',
#   'CL',
#   'MY',
#   'BR',
#   'RU',
#   'RU',
#   'CL',
#   'NZ',
#   'ES',
#   'ID',
#   'PT',
#   'VE',
#   'ID',
#   'US',
#   'AU',
#   'US',
#   'NC',
#   'US',
#   'RU',
#   'CL',
#   'JP',
#   'RU',
#   'VU',
#   'AR',
#   'PT',
#   'RU',
#   'MG',
#   'RE',
#   'KZ',
#   'NP',
#   'US',
#   'JP',
#   'LY',
#   'PL',
#   'CL',
#   'AR',
#   'TM',
#   'RU',
#   'ZA',
#   'RU',
#   'KZ',
#   'RU',
#   'AO',
#   'CD',
#   'AU',
#   'AR',
#   'US',
#   'MV',
#   'CA',
#   'NC',
#   'US',
#   'US',
#   'UA',
#   'ID',
#   'CN',
#   'IS',
#   'CA',
#   'RU',
#   'AU',
#   'MR',
#   'CU',
#   'UZ',
#   'US',
#   'US',
#   'SA',
#   'IN',
#   'NC',
#   'GL',
#   'IN',
#   'CD',
#   'MX',
#   'BR',
#   'NA',
#   'CN',
#   'RU',
#   'CL',
#   'IN',
#   'AU',
#   'SB',
#   'CA',
#   'IN',
#   'AU',
#   'US',
#   'CN',
#   'CN',
#   'VN',
#   'MG',
#   'MZ',
#   'US',
#   'IN',
#   'US',
#   'BR',
#   'NA',
#   'BR',
#   'JP',
#   'AF',
#   'PE',
#   'BR',
#   'NO',
#   'IN',
#   'SA',
#   'PH',
#   'CA',
#   'BR',
#   'GB',
#   'ZA',
#   'ID',
#   'CF',
#   'ID',
#   'BR',
#   'CA',
#   'CL',
#   'RU',
#   'SB',
#   'RU',
#   'SS',
#   'BR',
#   'RU',
#   'US',
#   'GF',
#   'SE',
#   'ML',
#   'RU',
#   'CN',
#   'AU',
#   'US',
#   'RU',
#   'AO',
#   'US',
#   'RU',
#   'CA',
#   'TO',
#   'GF',
#   'GP',
#   'RU',
#   'SJ',
#   'IN',
#   'MY',
#   'CN',
#   'JP',
#   'AU',
#   'EC',
#   'US',
#   'PK',
#   'CD',
#   'HK',
#   'RU',
#   'AU',
#   'US',
#   'CN',
#   'NZ',
#   'IS',
#   'RU',
#   'RU',
#   'IN',
#   'US',
#   'LR',
#   'MV',
#   'AR',
#   'LY',
#   'GL',
#   'ZM',
#   'MZ',
#   'NI',
#   'CI',
#   'PH',
#   'ID',
#   'PK',
#   'YE',
#   'AR',
#   'YE',
#   'US',
#   'ZA',
#   'BR',
#   'ID',
#   'US',
#   'BW',
#   'RU',
#   'RU',
#   'FI',
#   'ID',
#   'CA',
#   'JP',
#   'CL',
#   'IN',
#   'US',
#   'RU',
#   'IT',
#   'GQ',
#   'AU',
#   'PL',
#   'PE',
#   'ZA',
#   'AU',
#   'RU',
#   'US',
#   'TZ',
#   'CN',
#   'CI',
#   'JP',
#   'ID',
#   'BR',
#   'UY',
#   'MV',
#   'BR',
#   'LR',
#   'CA',
#   'NO',
#   'RU',
#   'PW',
#   'IS',
#   'FR',
#   'RU',
#   'PR',
#   'SA',
#   'CN',
#   'FR',
#   'IR',
#   'RU',
#   'NO',
#   'RU',
#   'US',
#   'JP',
#   'AU',
#   'HN',
#   'US',
#   'CA',
#   'CN',
#   'MX',
#   'TW',
#   'ML',
#   'BR',
#   'RU',
#   'US',
#   'RU',
#   'KZ',
#   'PT',
#   'CA',
#   'AU',
#   'IN',
#   'PE',
#   'US',
#   'SA',
#   'US',
#   'BR',
#   'CN',
#   'US',
#   'US',
#   'CF',
#   'MX',
#   'US',
#   'ES',
#   'VE',
#   'BW',
#   'GB',
#   'BR',
#   'SA',
#   'AU',
#   'PK',
#   'CD',
#   'NO',
#   'US',
#   'RU',
#   'US',
#   'US',
#   'AU',
#   'RU',
#   'RU',
#   'US',
#   'IR',
#   'GL',
#   'IQ',
#   'GL',
#   'JP',
#   'CA',
#   'NO',
#   'IS',
#   'IT',
#   'PG',
#   'FO',
#   'NA',
#   'US',
#   'BR',
#   'AU',
#   'ID',
#   'SD',
#   'NG',
#   'PH',
#   'RU',
#   'NC',
#   'GT',
#   'ID',
#   'RU',
#   'IS',
#   'PE',
#   'RU',
#   'GW',
#   'CA',
#   'ZM',
#   'MN',
#   'IN',
#   'IR',
#   'US',
#   'CN',
#   'MZ',
#   'US',
#   'NO',
#   'CV',
#   'PG',
#   'CG',
#   'CA',
#   'MX',
#   'MZ',
#   'US',
#   'ES',
#   'IE',
#   'US',
#   'US',
#   'CR',
#   'CD',
#   'VN',
#   'CN',
#   'IN',
#   'TZ',
#   'RU',
#   'GB',
#   'IN',
#   'IE',
#   'CD',
#   'PH',
#   'US',
#   'BR',
#   'US',
#   'US',
#   'CA',
#   'PH',
#   'CA',
#   'CD',
#   'CN',
#   'LY',
#   'IN',
#   'CA',
#   'PH',
#   'SO',
#   'RU',
#   'GQ',
#   'LK',
#   'BR',
#   'ET',
#   'US',
#   'US',
#   'BR',
#   'RO',
#   'RE',
#   'GH',
#   'PT',
#   'RU',
#   'BR',
#   'RU',
#   'BF',
#   'CA',
#   'CO',
#   'IL',
#   'BR',
#   'US',
#   'UA',
#   'RU',
#   'RU',
#   'CV',
#   'BR',
#   'ID',
#   'RU',
#   'BR',
#   'CN',
#   'RU',
#   'IR',
#   'ES',
#   'MX'],
#  'Date': [1595377565,
#   1595377565,
#   1595377565,
#   1595377565,
#   1595377565,
#   1595377565,
#   1595377274,
#   1595377340,
#   1595377566,
#   1595377566,
#   1595377566,
#   1595377418,
#   1595377566,
#   1595377266,
#   1595377565,
#   1595377566,
#   1595377566,
#   1595377566,
#   1595377566,
#   1595377566,
#   1595377567,
#   1595377567,
#   1595377567,
#   1595377567,
#   1595377567,
#   1595377567,
#   1595377567,
#   1595377567,
#   1595377567,
#   1595377567,
#   1595377567,
#   1595377567,
#   1595377567,
#   1595377568,
#   1595377298,
#   1595377513,
#   1595377568,
#   1595377325,
#   1595377568,
#   1595377568,
#   1595377568,
#   1595377568,
#   1595377568,
#   1595377271,
#   1595377340,
#   1595377388,
#   1595377461,
#   1595377569,
#   1595377569,
#   1595377569,
#   1595377569,
#   1595377569,
#   1595377569,
#   1595377569,
#   1595377569,
#   1595377569,
#   1595377569,
#   1595377569,
#   1595377569,
#   1595377570,
#   1595377570,
#   1595377570,
#   1595377570,
#   1595377570,
#   1595377570,
#   1595377500,
#   1595377570,
#   1595377570,
#   1595377570,
#   1595377570,
#   1595377570,
#   1595377571,
#   1595377571,
#   1595377571,
#   1595377571,
#   1595377571,
#   1595377571,
#   1595377571,
#   1595377571,
#   1595377572,
#   1595377572,
#   1595377470,
#   1595377572,
#   1595377572,
#   1595377572,
#   1595377572,
#   1595377573,
#   1595377573,
#   1595377573,
#   1595377307,
#   1595377573,
#   1595377573,
#   1595377573,
#   1595377573,
#   1595377573,
#   1595377573,
#   1595377573,
#   1595377573,
#   1595377349,
#   1595377574,
#   1595377574,
#   1595377574,
#   1595377574,
#   1595377574,
#   1595377574,
#   1595377574,
#   1595377574,
#   1595377574,
#   1595377574,
#   1595377480,
#   1595377575,
#   1595377461,
#   1595377575,
#   1595377575,
#   1595377575,
#   1595377357,
#   1595377575,
#   1595377277,
#   1595377575,
#   1595377575,
#   1595377575,
#   1595377575,
#   1595377575,
#   1595377575,
#   1595377575,
#   1595377576,
#   1595377576,
#   1595377576,
#   1595377576,
#   1595377576,
#   1595377576,
#   1595377515,
#   1595377576,
#   1595377576,
#   1595377576,
#   1595377576,
#   1595377577,
#   1595377577,
#   1595377577,
#   1595377577,
#   1595377577,
#   1595377577,
#   1595377577,
#   1595377577,
#   1595377577,
#   1595377577,
#   1595377577,
#   1595377577,
#   1595377577,
#   1595377578,
#   1595377578,
#   1595377578,
#   1595377578,
#   1595377317,
#   1595377578,
#   1595377350,
#   1595377578,
#   1595377344,
#   1595377578,
#   1595377578,
#   1595377578,
#   1595377578,
#   1595377579,
#   1595377558,
#   1595377579,
#   1595377579,
#   1595377579,
#   1595377579,
#   1595377579,
#   1595377579,
#   1595377579,
#   1595377579,
#   1595377579,
#   1595377579,
#   1595377579,
#   1595377579,
#   1595377580,
#   1595377580,
#   1595377580,
#   1595377512,
#   1595377580,
#   1595377580,
#   1595377325,
#   1595377580,
#   1595377580,
#   1595377580,
#   1595377580,
#   1595377581,
#   1595377581,
#   1595377505,
#   1595377581,
#   1595377581,
#   1595377445,
#   1595377581,
#   1595377581,
#   1595377581,
#   1595377581,
#   1595377581,
#   1595377581,
#   1595377311,
#   1595377581,
#   1595377582,
#   1595377582,
#   1595377335,
#   1595377582,
#   1595377582,
#   1595377582,
#   1595377582,
#   1595377582,
#   1595377582,
#   1595377582,
#   1595377583,
#   1595377583,
#   1595377432,
#   1595377583,
#   1595377583,
#   1595377583,
#   1595377583,
#   1595377583,
#   1595377583,
#   1595377583,
#   1595377583,
#   1595377297,
#   1595377584,
#   1595377584,
#   1595377314,
#   1595377585,
#   1595377502,
#   1595377585,
#   1595377538,
#   1595377585,
#   1595377585,
#   1595377346,
#   1595377585,
#   1595377585,
#   1595377585,
#   1595377472,
#   1595377585,
#   1595377586,
#   1595377586,
#   1595377586,
#   1595377586,
#   1595377586,
#   1595377586,
#   1595377586,
#   1595377586,
#   1595377411,
#   1595377297,
#   1595377586,
#   1595377586,
#   1595377586,
#   1595377586,
#   1595377586,
#   1595377586,
#   1595377586,
#   1595377587,
#   1595377391,
#   1595377462,
#   1595377587,
#   1595377587,
#   1595377587,
#   1595377587,
#   1595377532,
#   1595377587,
#   1595377342,
#   1595377587,
#   1595377587,
#   1595377587,
#   1595377587,
#   1595377587,
#   1595377588,
#   1595377588,
#   1595377588,
#   1595377588,
#   1595377588,
#   1595377363,
#   1595377588,
#   1595377588,
#   1595377588,
#   1595377588,
#   1595377588,
#   1595377588,
#   1595377588,
#   1595377589,
#   1595377589,
#   1595377589,
#   1595377589,
#   1595377340,
#   1595377589,
#   1595377589,
#   1595377589,
#   1595377589,
#   1595377589,
#   1595377589,
#   1595377589,
#   1595377589,
#   1595377589,
#   1595377590,
#   1595377590,
#   1595377590,
#   1595377409,
#   1595377590,
#   1595377590,
#   1595377590,
#   1595377590,
#   1595377590,
#   1595377590,
#   1595377590,
#   1595377590,
#   1595377590,
#   1595377591,
#   1595377591,
#   1595377591,
#   1595377591,
#   1595377591,
#   1595377591,
#   1595377591,
#   1595377591,
#   1595377591,
#   1595377591,
#   1595377592,
#   1595377592,
#   1595377506,
#   1595377592,
#   1595377592,
#   1595377592,
#   1595377592,
#   1595377592,
#   1595377509,
#   1595377592,
#   1595377580,
#   1595377554,
#   1595377538,
#   1595377592,
#   1595377593,
#   1595377593,
#   1595377593,
#   1595377593,
#   1595377593,
#   1595377593,
#   1595377593,
#   1595377593,
#   1595377593,
#   1595377593,
#   1595377593,
#   1595377594,
#   1595377594,
#   1595377302,
#   1595377594,
#   1595377594,
#   1595377594,
#   1595377594,
#   1595377594,
#   1595377594,
#   1595377594,
#   1595377594,
#   1595377594,
#   1595377344,
#   1595377595,
#   1595377595,
#   1595377318,
#   1595377595,
#   1595377595,
#   1595377595,
#   1595377595,
#   1595377595,
#   1595377595,
#   1595377412,
#   1595377574,
#   1595377596,
#   1595377596,
#   1595377596,
#   1595377596,
#   1595377596,
#   1595377596,
#   1595377596,
#   1595377596,
#   1595377596,
#   1595377596,
#   1595377597,
#   1595377597,
#   1595377597,
#   1595377597,
#   1595377597,
#   1595377597,
#   1595377597,
#   1595377597,
#   1595377524,
#   1595377597,
#   1595377597,
#   1595377597,
#   1595377597,
#   1595377597,
#   1595377597,
#   1595377598,
#   1595377598,
#   1595377598,
#   1595377349,
#   1595377598,
#   1595377598,
#   1595377598,
#   1595377598,
#   1595377598,
#   1595377598,
#   1595377598,
#   1595377598,
#   1595377598,
#   1595377598,
#   1595377599,
#   1595377525,
#   1595377599,
#   1595377599,
#   1595377599,
#   1595377599,
#   1595377599,
#   1595377599,
#   1595377599,
#   1595377599,
#   1595377599,
#   1595377599,
#   1595377600,
#   1595377600,
#   1595377600,
#   1595377600,
#   1595377600,
#   1595377600,
#   1595377600,
#   1595377600,
#   1595377600,
#   1595377600,
#   1595377600,
#   1595377600,
#   1595377600,
#   1595377600,
#   1595377600,
#   1595377601,
#   1595377601,
#   1595377601,
#   1595377558,
#   1595377601,
#   1595377601,
#   1595377601,
#   1595377601,
#   1595377601,
#   1595377601,
#   1595377601,
#   1595377602,
#   1595377602,
#   1595377602,
#   1595377602,
#   1595377414,
#   1595377602,
#   1595377602,
#   1595377602,
#   1595377602,
#   1595377602,
#   1595377344,
#   1595377602,
#   1595377383,
#   1595377342,
#   1595377603,
#   1595377603,
#   1595377425,
#   1595377603,
#   1595377513,
#   1595377603,
#   1595377312,
#   1595377603,
#   1595377603,
#   1595377446,
#   1595377603,
#   1595377603,
#   1595377603,
#   1595377603,
#   1595377604,
#   1595377276,
#   1595377604,
#   1595377604,
#   1595377319,
#   1595377604,
#   1595377438,
#   1595377604,
#   1595377604,
#   1595377604,
#   1595377604,
#   1595377604,
#   1595377604,
#   1595377604,
#   1595377605,
#   1595377605,
#   1595377605,
#   1595377605,
#   1595377605,
#   1595377461,
#   1595377605,
#   1595377438,
#   1595377605,
#   1595377605,
#   1595377605,
#   1595377605,
#   1595377605,
#   1595377606,
#   1595377606,
#   1595377606,
#   1595377606,
#   1595377606,
#   1595377606,
#   1595377606,
#   1595377606,
#   1595377345,
#   1595377606,
#   1595377606,
#   1595377606,
#   1595377606,
#   1595377607,
#   1595377607,
#   1595377607,
#   1595377513,
#   1595377607,
#   1595377607,
#   1595377607,
#   1595377607,
#   1595377607,
#   1595377607,
#   1595377607,
#   1595377458,
#   1595377385,
#   1595377607,
#   1595377608,
#   1595377606,
#   1595377608,
#   1595377608,
#   1595377525,
#   1595377608,
#   1595377608,
#   1595377608,
#   1595377608,
#   1595377608,
#   1595377608,
#   1595377608,
#   1595377609,
#   1595377609,
#   1595377609,
#   1595377609,
#   1595377609,
#   1595377609,
#   1595377579,
#   1595377609,
#   1595377369,
#   1595377609,
#   1595377609,
#   1595377609,
#   1595377609,
#   1595377609,
#   1595377609,
#   1595377609,
#   1595377444,
#   1595377610,
#   1595377610,
#   1595377610,
#   1595377610,
#   1595377332,
#   1595377387,
#   1595377610,
#   1595377610,
#   1595377610,
#   1595377610,
#   1595377610,
#   1595377610,
#   1595377611,
#   1595377611,
#   1595377611,
#   1595377611,
#   1595377611,
#   1595377611,
#   1595377611,
#   1595377611,
#   1595377611,
#   1595377611,
#   1595377611,
#   1595377612,
#   1595377421,
#   1595377612,
#   1595377612,
#   1595377612,
#   1595377612,
#   1595377612,
#   1595377612,
#   1595377612,
#   1595377612],
#  'Humidity': [58,
#   59,
#   54,
#   93,
#   93,
#   94,
#   94,
#   87,
#   60,
#   95,
#   84,
#   50,
#   42,
#   83,
#   92,
#   64,
#   88,
#   77,
#   68,
#   92,
#   43,
#   74,
#   77,
#   94,
#   100,
#   86,
#   66,
#   87,
#   64,
#   88,
#   27,
#   73,
#   86,
#   88,
#   82,
#   92,
#   73,
#   73,
#   83,
#   92,
#   41,
#   88,
#   77,
#   72,
#   76,
#   79,
#   65,
#   93,
#   87,
#   98,
#   87,
#   75,
#   85,
#   93,
#   83,
#   62,
#   78,
#   74,
#   77,
#   67,
#   65,
#   68,
#   68,
#   83,
#   82,
#   100,
#   94,
#   66,
#   63,
#   52,
#   76,
#   57,
#   53,
#   48,
#   94,
#   66,
#   81,
#   40,
#   100,
#   24,
#   71,
#   79,
#   87,
#   68,
#   75,
#   86,
#   72,
#   81,
#   51,
#   68,
#   88,
#   59,
#   92,
#   93,
#   27,
#   87,
#   82,
#   63,
#   86,
#   40,
#   90,
#   93,
#   94,
#   34,
#   72,
#   94,
#   77,
#   61,
#   83,
#   66,
#   93,
#   72,
#   87,
#   78,
#   66,
#   78,
#   17,
#   77,
#   77,
#   93,
#   72,
#   22,
#   81,
#   89,
#   93,
#   77,
#   94,
#   77,
#   61,
#   83,
#   94,
#   90,
#   53,
#   84,
#   85,
#   97,
#   68,
#   42,
#   87,
#   62,
#   87,
#   76,
#   74,
#   83,
#   94,
#   6,
#   87,
#   39,
#   81,
#   78,
#   26,
#   67,
#   78,
#   94,
#   97,
#   87,
#   60,
#   79,
#   82,
#   43,
#   8,
#   86,
#   100,
#   68,
#   87,
#   83,
#   56,
#   82,
#   50,
#   71,
#   44,
#   77,
#   62,
#   71,
#   83,
#   82,
#   53,
#   65,
#   96,
#   26,
#   52,
#   70,
#   78,
#   77,
#   52,
#   30,
#   44,
#   77,
#   72,
#   76,
#   35,
#   22,
#   80,
#   45,
#   76,
#   69,
#   81,
#   75,
#   79,
#   57,
#   54,
#   93,
#   88,
#   71,
#   87,
#   92,
#   72,
#   39,
#   31,
#   74,
#   52,
#   53,
#   78,
#   93,
#   94,
#   51,
#   80,
#   94,
#   66,
#   74,
#   78,
#   83,
#   75,
#   62,
#   94,
#   54,
#   87,
#   82,
#   73,
#   23,
#   64,
#   84,
#   88,
#   58,
#   59,
#   93,
#   73,
#   88,
#   72,
#   59,
#   72,
#   90,
#   20,
#   100,
#   78,
#   84,
#   67,
#   71,
#   12,
#   86,
#   89,
#   52,
#   70,
#   86,
#   88,
#   49,
#   25,
#   84,
#   87,
#   71,
#   72,
#   66,
#   8,
#   83,
#   95,
#   94,
#   71,
#   76,
#   33,
#   84,
#   28,
#   31,
#   78,
#   59,
#   65,
#   62,
#   88,
#   88,
#   43,
#   66,
#   90,
#   61,
#   74,
#   71,
#   42,
#   59,
#   90,
#   87,
#   88,
#   66,
#   67,
#   56,
#   99,
#   75,
#   77,
#   39,
#   91,
#   82,
#   76,
#   87,
#   88,
#   100,
#   19,
#   95,
#   43,
#   94,
#   78,
#   18,
#   82,
#   55,
#   82,
#   79,
#   15,
#   86,
#   68,
#   78,
#   87,
#   63,
#   85,
#   95,
#   86,
#   82,
#   87,
#   75,
#   76,
#   66,
#   69,
#   90,
#   78,
#   77,
#   65,
#   100,
#   81,
#   49,
#   36,
#   86,
#   37,
#   88,
#   66,
#   47,
#   88,
#   36,
#   43,
#   74,
#   87,
#   65,
#   65,
#   81,
#   87,
#   88,
#   31,
#   89,
#   80,
#   78,
#   81,
#   71,
#   60,
#   83,
#   93,
#   93,
#   35,
#   75,
#   67,
#   66,
#   35,
#   46,
#   83,
#   45,
#   94,
#   75,
#   96,
#   71,
#   54,
#   62,
#   89,
#   85,
#   98,
#   78,
#   82,
#   81,
#   84,
#   71,
#   56,
#   38,
#   50,
#   85,
#   71,
#   58,
#   48,
#   100,
#   30,
#   93,
#   98,
#   60,
#   79,
#   80,
#   87,
#   72,
#   84,
#   88,
#   98,
#   65,
#   93,
#   48,
#   33,
#   65,
#   65,
#   62,
#   56,
#   100,
#   99,
#   73,
#   94,
#   69,
#   91,
#   75,
#   41,
#   98,
#   46,
#   87,
#   73,
#   94,
#   78,
#   76,
#   76,
#   98,
#   62,
#   83,
#   64,
#   16,
#   61,
#   80,
#   50,
#   62,
#   83,
#   91,
#   83,
#   46,
#   32,
#   81,
#   81,
#   66,
#   38,
#   77,
#   53,
#   82,
#   50,
#   57,
#   88,
#   100,
#   71,
#   83,
#   87,
#   87,
#   25,
#   53,
#   83,
#   46,
#   94,
#   78,
#   95,
#   16,
#   79,
#   70,
#   58,
#   39,
#   91,
#   100,
#   88,
#   76,
#   76,
#   80,
#   81,
#   83,
#   64,
#   33,
#   83,
#   73,
#   62,
#   93,
#   13,
#   21,
#   72,
#   23,
#   66,
#   74,
#   87,
#   74,
#   71,
#   82,
#   69,
#   100,
#   39,
#   81,
#   88,
#   81,
#   90,
#   33,
#   91,
#   66,
#   69,
#   57,
#   74,
#   90,
#   87,
#   74,
#   83,
#   84,
#   77,
#   76,
#   73,
#   53,
#   80,
#   21,
#   26,
#   57,
#   83,
#   8,
#   93,
#   80,
#   71,
#   73,
#   68,
#   74,
#   80,
#   28,
#   88,
#   90,
#   58,
#   59,
#   100,
#   48,
#   83,
#   79,
#   78,
#   62,
#   91,
#   94,
#   80,
#   93,
#   91,
#   71,
#   30,
#   58,
#   78,
#   65,
#   66,
#   75,
#   57,
#   47,
#   65,
#   65,
#   78,
#   88,
#   83,
#   45,
#   68,
#   100,
#   85,
#   85,
#   100,
#   69,
#   69,
#   45,
#   93,
#   68,
#   91,
#   77,
#   81,
#   88,
#   92,
#   47,
#   44,
#   88,
#   82,
#   64,
#   66,
#   87,
#   91,
#   66,
#   74,
#   95,
#   78,
#   63,
#   93,
#   25,
#   93,
#   22,
#   69,
#   72],
#  'Lat': [19.73,
#   -33.92,
#   14.2,
#   -37.83,
#   58.03,
#   -3.42,
#   33.6,
#   63.75,
#   -23.12,
#   55.96,
#   5.38,
#   42.6,
#   61.95,
#   57.51,
#   -53.15,
#   32.33,
#   36.26,
#   43.37,
#   55.28,
#   60.38,
#   40.87,
#   -9.8,
#   -42.78,
#   -37.72,
#   -24.87,
#   -54.8,
#   -22.12,
#   18.82,
#   -8.93,
#   28.07,
#   26.73,
#   -4.27,
#   -24.79,
#   35.13,
#   -16.48,
#   -0.74,
#   32.67,
#   42.1,
#   -21.21,
#   -38.55,
#   57.79,
#   71.69,
#   -10.62,
#   -33.65,
#   -45.42,
#   -0.88,
#   22.89,
#   9.23,
#   7.53,
#   -17.4,
#   5.66,
#   -22.67,
#   -11.1,
#   62.27,
#   -46.19,
#   28.99,
#   -4.24,
#   71.29,
#   -20.34,
#   27.98,
#   33.99,
#   -0.22,
#   42.06,
#   -46.6,
#   3.07,
#   -33.93,
#   -22.97,
#   23.7,
#   77.48,
#   71.97,
#   -33.87,
#   -21.2,
#   68.82,
#   40.8,
#   33.95,
#   22.08,
#   9.47,
#   38.42,
#   35,
#   43.91,
#   11.78,
#   16.86,
#   65.46,
#   63.92,
#   -0.91,
#   18.03,
#   18.04,
#   -42.72,
#   41.37,
#   -21.36,
#   13.22,
#   72.79,
#   8.06,
#   2.02,
#   -33.59,
#   -33.7,
#   47.38,
#   54.72,
#   -3.8,
#   54.78,
#   71.92,
#   53.33,
#   35.62,
#   -19.53,
#   65.53,
#   3.87,
#   50.18,
#   60.47,
#   11.42,
#   -42.88,
#   -34.53,
#   36.62,
#   59.7,
#   18.09,
#   33.73,
#   21.46,
#   39.07,
#   -20.52,
#   -20.21,
#   49.42,
#   63.05,
#   -22.96,
#   69.45,
#   32.3,
#   65.83,
#   -20.41,
#   17.02,
#   42.03,
#   42.6,
#   71.04,
#   -0.95,
#   32.44,
#   -12.74,
#   -24.8,
#   34.37,
#   -34.42,
#   -2.02,
#   53.05,
#   27.92,
#   -26.53,
#   -33.01,
#   6.88,
#   19.22,
#   -5.2,
#   7.04,
#   46.04,
#   -32.25,
#   42.8,
#   -8.1,
#   -3.28,
#   18.69,
#   -0.6,
#   41,
#   73.51,
#   6.5,
#   69.49,
#   -20.78,
#   39.05,
#   43.75,
#   -19.65,
#   39.47,
#   -1.57,
#   55.51,
#   37.61,
#   50.12,
#   -3.7,
#   34.17,
#   37.73,
#   39.93,
#   66.04,
#   17.16,
#   25.26,
#   -45.87,
#   -46.28,
#   -46.13,
#   47.67,
#   -25.24,
#   37.36,
#   7.27,
#   -33.02,
#   34.17,
#   -3.67,
#   -17.8,
#   47.97,
#   48.8,
#   68.75,
#   51.03,
#   43.22,
#   54.44,
#   50.63,
#   39.65,
#   20.5,
#   5.56,
#   -22.45,
#   60.68,
#   41.3,
#   61.28,
#   65.61,
#   11.67,
#   62.46,
#   -6.22,
#   63.08,
#   -21.15,
#   -27.58,
#   6.75,
#   14.16,
#   33.97,
#   -14.8,
#   55.74,
#   13.22,
#   62,
#   -5.58,
#   -19.06,
#   -33.46,
#   5.41,
#   -6.64,
#   50.68,
#   52.53,
#   -30.69,
#   -39.2,
#   42.78,
#   -8.35,
#   38.52,
#   5.66,
#   -8.65,
#   45.02,
#   -28.77,
#   64.84,
#   -21.69,
#   42.44,
#   56.91,
#   -37.62,
#   35.73,
#   69.7,
#   -19.55,
#   -38,
#   38.57,
#   57.7,
#   -15.72,
#   -20.94,
#   53.17,
#   26.72,
#   37.1,
#   43.66,
#   31.45,
#   50.71,
#   -25.4,
#   -45.87,
#   39.51,
#   45.65,
#   -28.78,
#   66.32,
#   52.54,
#   59.6,
#   -8.84,
#   -8.74,
#   -20.73,
#   -40.81,
#   40.6,
#   2.67,
#   56.18,
#   -20.65,
#   36.04,
#   27.1,
#   52.04,
#   -8.19,
#   27.12,
#   63.84,
#   50.25,
#   58.13,
#   -14.47,
#   20.52,
#   20.66,
#   40.43,
#   37.27,
#   39.18,
#   18.22,
#   13.15,
#   -20.97,
#   60.14,
#   20.47,
#   -2.95,
#   18.73,
#   -30.18,
#   -26.65,
#   36.62,
#   62.07,
#   -29.95,
#   8.13,
#   -34.58,
#   -8.77,
#   51.63,
#   25.52,
#   -32.55,
#   43.41,
#   43.65,
#   29.96,
#   9.6,
#   -14.27,
#   -17.88,
#   41.28,
#   25.3,
#   40.04,
#   -1.83,
#   -17.47,
#   -14.64,
#   36.22,
#   30.44,
#   -13.7,
#   -4.88,
#   66.31,
#   24.58,
#   29.97,
#   11,
#   66.15,
#   -30.26,
#   55.8,
#   -29.27,
#   -8.61,
#   6.51,
#   -6.88,
#   -7.55,
#   48.93,
#   -41.87,
#   64.38,
#   -9.43,
#   67.68,
#   9.53,
#   2.82,
#   66.03,
#   21.32,
#   4.93,
#   63.83,
#   18.44,
#   69.3,
#   25.7,
#   -20.32,
#   46.92,
#   65.58,
#   -10.71,
#   44.67,
#   70.63,
#   60.75,
#   -18.65,
#   4.25,
#   16.06,
#   53.75,
#   78.22,
#   22.08,
#   6.2,
#   40.28,
#   24.34,
#   -38.27,
#   -0.95,
#   64.86,
#   27.74,
#   -2.17,
#   22.29,
#   55.7,
#   -34.2,
#   34.88,
#   18.8,
#   -35.17,
#   64.54,
#   62.55,
#   67.8,
#   16.05,
#   42.16,
#   6.3,
#   6.62,
#   -36.89,
#   32.76,
#   60.92,
#   -11.74,
#   -13.31,
#   12.79,
#   5.79,
#   8,
#   -5.67,
#   28.89,
#   13.92,
#   -43.3,
#   14.4,
#   32.22,
#   -34,
#   -20.28,
#   5.89,
#   41.14,
#   -19.67,
#   66,
#   67.45,
#   61.56,
#   -3.45,
#   60.82,
#   28.37,
#   -35.33,
#   13.97,
#   34.64,
#   56.26,
#   38.24,
#   1.63,
#   -34.73,
#   50.49,
#   -15.03,
#   -33.3,
#   -20.74,
#   42.9,
#   37.23,
#   -8.93,
#   31.86,
#   6.49,
#   40.81,
#   -0.32,
#   -29.68,
#   -34.48,
#   5.67,
#   -15.97,
#   6.07,
#   49.68,
#   63.73,
#   65.85,
#   7.5,
#   64.25,
#   43.17,
#   61.03,
#   18.49,
#   17.15,
#   36.1,
#   46.42,
#   33.6,
#   54.43,
#   67.67,
#   52.7,
#   38.89,
#   36.3,
#   -35.12,
#   15,
#   38.42,
#   49.65,
#   27.67,
#   17.67,
#   22.62,
#   20.2,
#   -22.41,
#   53.73,
#   37.46,
#   69.38,
#   47.8,
#   41.54,
#   70.47,
#   -23.7,
#   10.57,
#   -10.67,
#   57.05,
#   17.49,
#   44.69,
#   -20.33,
#   48.23,
#   40.13,
#   41.8,
#   6.54,
#   32.65,
#   29.37,
#   41.35,
#   7.77,
#   -26.02,
#   50.83,
#   -0.12,
#   18.39,
#   -32.25,
#   25.12,
#   2.74,
#   62.58,
#   33.23,
#   62.1,
#   45.52,
#   33.19,
#   -17,
#   46.49,
#   63.01,
#   40.52,
#   32.87,
#   66.94,
#   36.32,
#   64.18,
#   34.67,
#   68.22,
#   70.37,
#   65.68,
#   46.62,
#   -2.57,
#   62.23,
#   -18.06,
#   64.5,
#   -21.64,
#   -31.95,
#   4.14,
#   19.11,
#   7.85,
#   7.45,
#   67.67,
#   -20.93,
#   14.3,
#   1.17,
#   63.28,
#   64.89,
#   -9.29,
#   57.2,
#   11.28,
#   65.28,
#   -11.36,
#   49.49,
#   9.73,
#   31.9,
#   32.9,
#   49.28,
#   -12.97,
#   34.9,
#   69.13,
#   14.9,
#   -2.67,
#   -4.27,
#   49.87,
#   17.83,
#   -14.54,
#   31.46,
#   39.89,
#   52.05,
#   38.04,
#   59.64,
#   10.15,
#   -6.05,
#   16.47,
#   23.19,
#   26.37,
#   -1.25,
#   54.28,
#   51.03,
#   24.17,
#   55.25,
#   0.52,
#   5.5,
#   35.24,
#   -8.01,
#   39.45,
#   42.33,
#   49.15,
#   12.18,
#   52.78,
#   -3.48,
#   49.6,
#   29.16,
#   9.68,
#   50.7,
#   14.31,
#   11.28,
#   53.53,
#   3.46,
#   6.12,
#   -10.41,
#   8.53,
#   42.25,
#   39.01,
#   -9.45,
#   46.43,
#   -21.37,
#   4.87,
#   33.08,
#   67.47,
#   -5.81,
#   57.47,
#   14.1,
#   50.32,
#   8.41,
#   31.61,
#   -12.82,
#   39.41,
#   50.81,
#   66.77,
#   42,
#   14.92,
#   -2.04,
#   -2.88,
#   61.73,
#   -1.2,
#   39.74,
#   58.01,
#   31.27,
#   28.66,
#   20.87],
#  'Lng': [-155.09,
#   25.57,
#   24.67,
#   140.77,
#   56.76,
#   114.85,
#   73.07,
#   -68.51,
#   -134.97,
#   97.82,
#   -52.95,
#   -73.97,
#   159.23,
#   72.4,
#   -70.92,
#   -117.03,
#   2.75,
#   -124.22,
#   -114.77,
#   92.63,
#   71.11,
#   -139.03,
#   147.06,
#   -72.23,
#   113.63,
#   -68.3,
#   14.28,
#   76.12,
#   125.41,
#   95.33,
#   33.94,
#   34.37,
#   -50.01,
#   140.3,
#   -151.75,
#   -90.35,
#   -17.1,
#   -79.24,
#   -159.78,
#   -58.74,
#   -152.41,
#   128.87,
#   150.67,
#   115.33,
#   167.72,
#   131.25,
#   -109.91,
#   29.83,
#   -12.51,
#   32.23,
#   -53.78,
#   167.48,
#   -77.61,
#   24.7,
#   168.86,
#   -80.9,
#   142.84,
#   -156.79,
#   57.76,
#   -114.06,
#   -96.37,
#   20.87,
#   -1.6,
#   168.33,
#   172.79,
#   18.42,
#   -42.03,
#   113.03,
#   -69.36,
#   102.5,
#   121.9,
#   -175.2,
#   -51.19,
#   -124.16,
#   130.95,
#   -159.32,
#   12.03,
#   -121.42,
#   132.22,
#   67.25,
#   -72.44,
#   -99.89,
#   12.2,
#   127.47,
#   122.88,
#   73.02,
#   -71.74,
#   170.97,
#   -73.41,
#   55.77,
#   80.32,
#   -56.15,
#   -1.73,
#   112.93,
#   26.89,
#   -53.46,
#   -61.86,
#   158.62,
#   102.27,
#   -127.17,
#   114.08,
#   6.52,
#   -5.28,
#   -54.04,
#   72.52,
#   -67.92,
#   30.1,
#   166.1,
#   -7.48,
#   147.33,
#   20.04,
#   -121.92,
#   30.79,
#   -15.98,
#   135.98,
#   -71.14,
#   63.58,
#   57.52,
#   57.76,
#   31.92,
#   179.32,
#   14.51,
#   -133.04,
#   -9.24,
#   21.69,
#   57.7,
#   54.09,
#   -8.16,
#   -84.38,
#   27.85,
#   100.35,
#   105.82,
#   -60.15,
#   -53.31,
#   107.36,
#   19.23,
#   147.27,
#   158.65,
#   96.17,
#   151.83,
#   17.94,
#   73.1,
#   -104.7,
#   -35.46,
#   134.26,
#   -73.11,
#   115.77,
#   93.45,
#   156.84,
#   -39.27,
#   12.92,
#   73.08,
#   -76.45,
#   80.55,
#   4.78,
#   88.4,
#   117.13,
#   -27.98,
#   -81.72,
#   17.33,
#   -118.78,
#   9.26,
#   47.5,
#   -122.49,
#   -5.54,
#   128.18,
#   77.58,
#   -25.67,
#   8.53,
#   -17.34,
#   -89.07,
#   63.47,
#   170.5,
#   169.85,
#   167.68,
#   -52.73,
#   130.99,
#   120.4,
#   28.68,
#   27.91,
#   -97.14,
#   152.43,
#   -63.17,
#   80.44,
#   44.47,
#   161.3,
#   -113.82,
#   27.92,
#   56.32,
#   -96.99,
#   66.96,
#   -10.07,
#   95.32,
#   18.97,
#   11.83,
#   -96.17,
#   108.01,
#   -37.64,
#   92.75,
#   -114.35,
#   -57.75,
#   27.67,
#   149.2,
#   153.3,
#   -11.37,
#   38.9,
#   36.66,
#   -57.29,
#   -97.86,
#   -59.52,
#   132.43,
#   -44.39,
#   -169.92,
#   -70.65,
#   100.34,
#   -51.99,
#   156.12,
#   84.79,
#   -70.95,
#   173.88,
#   -9.06,
#   113.61,
#   -28.7,
#   -67.62,
#   115.22,
#   -93.22,
#   114.6,
#   -147.72,
#   165.68,
#   -123.33,
#   118.26,
#   -73.65,
#   140.83,
#   170.31,
#   169.27,
#   -57.56,
#   -7.9,
#   93.28,
#   46.32,
#   55.29,
#   63.58,
#   85.91,
#   -113.58,
#   145.13,
#   12.98,
#   22.41,
#   -70.48,
#   -67.5,
#   54.37,
#   38.18,
#   32.04,
#   -179.17,
#   62.49,
#   54.31,
#   13.23,
#   24.99,
#   139.5,
#   -63,
#   -124.16,
#   72.89,
#   -117.6,
#   166.53,
#   -114.98,
#   -82.45,
#   33.95,
#   114.97,
#   114.98,
#   -22.43,
#   -117.8,
#   68.59,
#   132.27,
#   -13.05,
#   -74.94,
#   71.72,
#   -87.18,
#   -84.53,
#   42.51,
#   79.92,
#   164.7,
#   -45.24,
#   84.23,
#   25.95,
#   -103.68,
#   -50.21,
#   15.16,
#   101.77,
#   49.57,
#   -71.34,
#   77.3,
#   150.86,
#   160.7,
#   -102.43,
#   90.22,
#   115.7,
#   -124.22,
#   111.98,
#   122.3,
#   105.98,
#   50.17,
#   36.89,
#   -70.1,
#   91.7,
#   -111.73,
#   -44.87,
#   16.33,
#   -39.55,
#   136.15,
#   61.84,
#   -76.22,
#   -66.9,
#   14.14,
#   80.83,
#   40.21,
#   122.67,
#   -65.71,
#   -50.51,
#   -4.39,
#   26.71,
#   120.47,
#   18.27,
#   112.21,
#   -35.71,
#   -125.55,
#   -73.82,
#   -173.3,
#   159.95,
#   53.15,
#   31.66,
#   -60.67,
#   60.17,
#   -158.01,
#   -52.33,
#   20.26,
#   1.41,
#   139.9,
#   100.18,
#   118.57,
#   -98,
#   -171,
#   22.22,
#   -90.17,
#   147.92,
#   -137.51,
#   -173.98,
#   -54.38,
#   -61.77,
#   127.27,
#   15.64,
#   85.67,
#   102.17,
#   97.2,
#   124.16,
#   141.97,
#   -80.73,
#   -147.8,
#   66.64,
#   16.23,
#   114.16,
#   37.38,
#   142.15,
#   -76.9,
#   110.4,
#   173.17,
#   -21.92,
#   155.55,
#   130.41,
#   79.75,
#   -72.33,
#   -10.8,
#   73.07,
#   -60.32,
#   12.57,
#   -46.05,
#   24.43,
#   35.24,
#   -85.12,
#   -6.61,
#   124.29,
#   132.75,
#   64.41,
#   44.15,
#   -65.1,
#   46.47,
#   -98.2,
#   24.73,
#   -42.34,
#   95.32,
#   -73.36,
#   22.27,
#   111.5,
#   153.68,
#   23.6,
#   104.25,
#   -115.8,
#   129.48,
#   -72.42,
#   74.57,
#   -120.46,
#   62.94,
#   16.26,
#   11.31,
#   135.87,
#   19.42,
#   -73.78,
#   26.53,
#   116.85,
#   133.91,
#   -77.4,
#   36.13,
#   117.28,
#   -6.59,
#   140.39,
#   102.35,
#   -53.81,
#   -54.33,
#   73,
#   -54.97,
#   -8.13,
#   -83.67,
#   8.83,
#   74.49,
#   134.62,
#   -15.21,
#   5.6,
#   76.11,
#   -66.83,
#   42.63,
#   120.37,
#   3.91,
#   56.92,
#   113.6,
#   12.69,
#   115.17,
#   -76.51,
#   139.8,
#   139.27,
#   -83.23,
#   -82.45,
#   -108.42,
#   120.57,
#   -96.13,
#   120.31,
#   1.01,
#   -47.56,
#   119.77,
#   -122.43,
#   178.42,
#   67.71,
#   -8.62,
#   -68.59,
#   133.88,
#   72.64,
#   -77.83,
#   -135.33,
#   44.13,
#   -75.49,
#   -40.29,
#   129.5,
#   -88.2,
#   -85.42,
#   21.99,
#   -115.47,
#   -94.97,
#   -2.85,
#   -72.22,
#   22.4,
#   -0.14,
#   -51.29,
#   42.45,
#   148.62,
#   62.33,
#   23.78,
#   6.13,
#   -87.58,
#   126.7,
#   -122.68,
#   -82.53,
#   145.43,
#   135.88,
#   112.47,
#   -107.55,
#   59.22,
#   -53.67,
#   41.88,
#   -51.72,
#   137.27,
#   -135.01,
#   31.11,
#   -18.09,
#   10.7,
#   150.8,
#   -6.59,
#   13.84,
#   -165.41,
#   -41.05,
#   141.43,
#   96.13,
#   37.33,
#   9.78,
#   126.58,
#   53.09,
#   165.33,
#   -91.92,
#   108.97,
#   118.33,
#   -23.71,
#   -76.01,
#   56.91,
#   -15.83,
#   -126.83,
#   29.56,
#   105.92,
#   79.02,
#   54.37,
#   -105.96,
#   120.73,
#   40.52,
#   -117.02,
#   18.61,
#   -24.5,
#   141.3,
#   15.28,
#   -99.36,
#   -98.85,
#   40.67,
#   -100.44,
#   4.27,
#   -9.52,
#   -84.9,
#   -151.55,
#   -85.45,
#   26.92,
#   107.6,
#   116.61,
#   79.65,
#   31.42,
#   37.46,
#   -4.22,
#   72.43,
#   -7.27,
#   25.2,
#   120.88,
#   -106.61,
#   -34.86,
#   -86.18,
#   -83.33,
#   -55.35,
#   125.51,
#   -108.28,
#   23.43,
#   117.43,
#   16.14,
#   78.1,
#   -127.42,
#   121.11,
#   49.18,
#   49.35,
#   8.55,
#   81.12,
#   -36.43,
#   34.8,
#   -75.83,
#   -77.43,
#   -46.3,
#   26.4,
#   55.62,
#   -2.24,
#   -16.33,
#   78.7,
#   -61.3,
#   31.12,
#   -1.63,
#   -122.8,
#   -75.59,
#   34.76,
#   -42.73,
#   -74.36,
#   30.14,
#   123.37,
#   48.33,
#   -23.51,
#   -45.96,
#   108.27,
#   130.28,
#   -46.02,
#   98.52,
#   55.67,
#   56.81,
#   -17.92,
#   -90.4],
#  'Max Temp': [84.2,
#   62.6,
#   77.47,
#   48.2,
#   60.8,
#   78.8,
#   69.8,
#   48.2,
#   66.43,
#   61.32,
#   78.08,
#   80.01,
#   67.95,
#   55.04,
#   19.4,
#   77,
#   71.6,
#   64.4,
#   69.8,
#   52.65,
#   71.6,
#   79.57,
#   48.99,
#   44.71,
#   59,
#   32,
#   61,
#   75.33,
#   63.16,
#   75.51,
#   89.6,
#   59.05,
#   57.29,
#   80.6,
#   76.87,
#   69.01,
#   69.8,
#   75.99,
#   78.8,
#   51.01,
#   75.2,
#   49.5,
#   77.45,
#   55,
#   40.35,
#   80.26,
#   93.2,
#   72.63,
#   76.8,
#   48.96,
#   77.72,
#   67.96,
#   60.06,
#   57.2,
#   39,
#   84.2,
#   83.01,
#   35.6,
#   68,
#   72.54,
#   84.99,
#   73.26,
#   71.6,
#   39,
#   78.04,
#   48,
#   69.8,
#   86,
#   46.89,
#   59.18,
#   48.2,
#   77,
#   51.8,
#   66.99,
#   82,
#   84.2,
#   76.64,
#   87.01,
#   73.4,
#   74.01,
#   84.2,
#   84.2,
#   50,
#   60.04,
#   79.68,
#   80.29,
#   82.9,
#   48.13,
#   82.4,
#   64.4,
#   82.4,
#   48.36,
#   71.82,
#   76.46,
#   66.29,
#   65.19,
#   64.4,
#   53.44,
#   77,
#   73.4,
#   46.18,
#   54,
#   75.2,
#   72.01,
#   48.04,
#   74.59,
#   63,
#   56.86,
#   75.45,
#   48.99,
#   48.2,
#   64.4,
#   62.01,
#   82.4,
#   86,
#   83.77,
#   82.4,
#   68,
#   68,
#   60.84,
#   48.65,
#   69.8,
#   42.8,
#   69.3,
#   57.2,
#   68,
#   80.6,
#   69.01,
#   78.8,
#   56.68,
#   75.2,
#   68,
#   75.2,
#   61.77,
#   69.37,
#   48,
#   84.51,
#   68,
#   75.02,
#   57.99,
#   48.2,
#   83.25,
#   86,
#   71.6,
#   75.2,
#   73.99,
#   57,
#   75.51,
#   81.16,
#   77.43,
#   90,
#   84.52,
#   79,
#   40.15,
#   73.72,
#   51.8,
#   68.74,
#   68.95,
#   71.01,
#   51.48,
#   100.4,
#   73.36,
#   60.8,
#   64.4,
#   57.99,
#   82,
#   48.65,
#   62.6,
#   72,
#   51.8,
#   96.8,
#   84.69,
#   46.99,
#   46,
#   39,
#   69.01,
#   51.8,
#   76.26,
#   70.45,
#   65.57,
#   88,
#   84.33,
#   75.2,
#   64.87,
#   64.4,
#   78.4,
#   81,
#   69.01,
#   64,
#   77,
#   73.4,
#   93.96,
#   78.75,
#   46.4,
#   48.2,
#   84.99,
#   57.85,
#   46.4,
#   81.21,
#   77,
#   78.46,
#   62.6,
#   64.99,
#   62.01,
#   76.69,
#   61.07,
#   68,
#   76.15,
#   78.8,
#   82.4,
#   64.87,
#   77.07,
#   80.6,
#   46.4,
#   77,
#   75.49,
#   52.63,
#   56.88,
#   52.88,
#   52,
#   66.99,
#   76.62,
#   69.39,
#   84.2,
#   80.6,
#   79,
#   51.8,
#   55.4,
#   69.8,
#   95,
#   57.02,
#   49.8,
#   79,
#   50.07,
#   72.5,
#   51.8,
#   73.4,
#   55.92,
#   66.2,
#   64.4,
#   60.8,
#   78.91,
#   97,
#   62.6,
#   68.54,
#   57.99,
#   57.36,
#   37.4,
#   94.84,
#   66.34,
#   59.94,
#   53.22,
#   62.06,
#   57.51,
#   68,
#   61.21,
#   64.4,
#   46,
#   59,
#   84.27,
#   66.2,
#   71.71,
#   105.8,
#   80.01,
#   57.72,
#   80.6,
#   83.89,
#   50,
#   86.5,
#   54.86,
#   71.6,
#   93.27,
#   81.48,
#   66.2,
#   89.6,
#   88,
#   71.6,
#   82.4,
#   75.76,
#   51.75,
#   75,
#   70.52,
#   82.4,
#   65.64,
#   64.4,
#   58.68,
#   55.29,
#   55.4,
#   80.6,
#   55.99,
#   84.18,
#   73.4,
#   74.16,
#   57,
#   64.4,
#   78.37,
#   79.38,
#   80.44,
#   68.54,
#   60.8,
#   72,
#   62.33,
#   95,
#   73.27,
#   55.4,
#   61.29,
#   77,
#   80.65,
#   63,
#   76.73,
#   44.69,
#   81.18,
#   93.2,
#   80.17,
#   52.36,
#   65.01,
#   54,
#   28.4,
#   65.84,
#   68.18,
#   78.39,
#   66.2,
#   60.8,
#   46.4,
#   50,
#   84.2,
#   58.55,
#   73.33,
#   78.8,
#   58.24,
#   84.2,
#   75.2,
#   53.01,
#   82.89,
#   81.41,
#   64.24,
#   68,
#   68,
#   48.45,
#   57.33,
#   73.99,
#   80.02,
#   69.03,
#   78.8,
#   74.71,
#   82.4,
#   66.72,
#   48.2,
#   76.98,
#   78.8,
#   75.88,
#   86,
#   51.33,
#   75.2,
#   55.4,
#   75.67,
#   74.39,
#   84,
#   61,
#   44.01,
#   86,
#   84.24,
#   53.44,
#   51.8,
#   64.49,
#   72.73,
#   81.99,
#   86,
#   77,
#   83.39,
#   51.01,
#   75,
#   57.2,
#   49.95,
#   51.6,
#   78.26,
#   71.37,
#   82,
#   78.84,
#   74.89,
#   63.48,
#   42.89,
#   81.27,
#   91.4,
#   55.78,
#   61.83,
#   82.29,
#   84.2,
#   50.83,
#   46.4,
#   82.15,
#   55.4,
#   73.24,
#   71.6,
#   86,
#   50.86,
#   79.34,
#   66.99,
#   54.66,
#   77,
#   66.29,
#   53.17,
#   59,
#   49.35,
#   54.75,
#   68.67,
#   73.02,
#   86,
#   71.31,
#   80.6,
#   71.11,
#   77,
#   74.7,
#   73.4,
#   65.71,
#   83.77,
#   70.83,
#   71.02,
#   70.68,
#   50,
#   47.01,
#   75.2,
#   52.18,
#   73.99,
#   57.2,
#   78.01,
#   87.8,
#   77,
#   69.8,
#   86,
#   60.04,
#   52.09,
#   63.07,
#   88,
#   86,
#   50,
#   80.6,
#   95,
#   78.39,
#   80.44,
#   82.69,
#   91,
#   88.14,
#   62.6,
#   65.98,
#   75,
#   55.2,
#   70.11,
#   77,
#   42.8,
#   50,
#   80.67,
#   59.85,
#   57.2,
#   86,
#   75.99,
#   75,
#   74.14,
#   71.6,
#   80.6,
#   67.73,
#   115,
#   87.01,
#   64.99,
#   86,
#   52,
#   62.01,
#   78.8,
#   71.6,
#   50,
#   84.7,
#   71.17,
#   50,
#   78.8,
#   65.43,
#   90,
#   82.4,
#   73.4,
#   73.4,
#   57.25,
#   91.4,
#   69.8,
#   56.23,
#   79.79,
#   53.6,
#   84.99,
#   44.6,
#   60.12,
#   51.8,
#   59,
#   84.29,
#   44.6,
#   56.08,
#   60.01,
#   71.83,
#   44.6,
#   75.4,
#   93.94,
#   73.63,
#   83.95,
#   58.6,
#   71.6,
#   82.4,
#   76.96,
#   64.49,
#   49.06,
#   70.65,
#   60.37,
#   79.74,
#   57.2,
#   53.94,
#   71.11,
#   81.99,
#   78.8,
#   91.4,
#   70.63,
#   69.8,
#   107.6,
#   50,
#   77.04,
#   83.73,
#   77,
#   69.8,
#   75.52,
#   66.34,
#   96.8,
#   71.6,
#   50.4,
#   88,
#   62.6,
#   71.6,
#   70.57,
#   80.6,
#   86,
#   82.63,
#   66.22,
#   58.55,
#   53.01,
#   81.39,
#   52.79,
#   71.1,
#   83.8,
#   84.99,
#   84.2,
#   82,
#   80.6,
#   70,
#   83.12,
#   75.2,
#   72.18,
#   68.4,
#   70.74,
#   80.6,
#   62.6,
#   78.8,
#   89.08,
#   64.4,
#   73.4,
#   79.56,
#   73.26,
#   56.7,
#   75,
#   84,
#   74.86,
#   59,
#   64.4,
#   75.47,
#   68,
#   44.26,
#   78.8,
#   59.47,
#   87.35,
#   78.8,
#   80.6,
#   73.99,
#   67.3,
#   84.2,
#   60.8,
#   55.69,
#   77,
#   80.6,
#   72.73,
#   81.55,
#   64.4,
#   74.89,
#   78.08,
#   60.8,
#   71.82,
#   73.4,
#   83.89],
#  'Wind Speed': [11.41,
#   16.11,
#   6.73,
#   5.82,
#   4.47,
#   2.24,
#   2.62,
#   10.29,
#   17.36,
#   3.02,
#   8.12,
#   5.17,
#   2.66,
#   3.65,
#   4.7,
#   17.22,
#   2.24,
#   17.22,
#   2.24,
#   0.89,
#   9.17,
#   14.99,
#   1.99,
#   2.06,
#   6.93,
#   5.82,
#   1.01,
#   8.79,
#   5.1,
#   1.88,
#   12.75,
#   6.58,
#   3.69,
#   10.29,
#   22.97,
#   7,
#   12.75,
#   3.36,
#   17.22,
#   23,
#   8.05,
#   5.12,
#   15.9,
#   14.05,
#   4.29,
#   7.09,
#   17.22,
#   4.45,
#   5.79,
#   3.44,
#   8.01,
#   19.89,
#   7.74,
#   8.05,
#   3,
#   4.7,
#   0.92,
#   8.05,
#   12.75,
#   19.44,
#   12.75,
#   0.89,
#   3.36,
#   3,
#   5.73,
#   2.24,
#   6.93,
#   4.47,
#   5.1,
#   12.91,
#   18.34,
#   5.82,
#   4.7,
#   1.01,
#   2.24,
#   14.99,
#   4.72,
#   6.93,
#   5.82,
#   3.09,
#   18.07,
#   5.82,
#   2.24,
#   18.9,
#   7.99,
#   5.37,
#   8.05,
#   2.28,
#   3.36,
#   8.05,
#   6.93,
#   7.83,
#   4.09,
#   1.05,
#   10.13,
#   6.6,
#   10.29,
#   7.63,
#   6.46,
#   9.17,
#   18.21,
#   4.7,
#   3.36,
#   5.46,
#   10.04,
#   0.22,
#   11.18,
#   6.04,
#   3.94,
#   8.05,
#   5.82,
#   10.29,
#   6.71,
#   6.93,
#   8.05,
#   19.19,
#   11.41,
#   12.75,
#   12.75,
#   10.58,
#   5.46,
#   13.87,
#   9.17,
#   8.77,
#   11.41,
#   12.75,
#   5.82,
#   1.01,
#   2.08,
#   2.84,
#   2.24,
#   3.6,
#   5.82,
#   4.41,
#   3.83,
#   3.38,
#   8.39,
#   13.42,
#   2.46,
#   9.17,
#   1.12,
#   18.03,
#   23.04,
#   4.7,
#   3.36,
#   5.41,
#   8.05,
#   5.08,
#   20.4,
#   8.05,
#   9.28,
#   3.27,
#   0.51,
#   10.09,
#   2.06,
#   24.61,
#   10.76,
#   4.36,
#   7.9,
#   9.95,
#   5.82,
#   6.58,
#   6.71,
#   25.28,
#   5.82,
#   5.82,
#   5.73,
#   4.7,
#   3,
#   5.82,
#   4.7,
#   7.72,
#   18.01,
#   8.01,
#   3,
#   20.8,
#   11.41,
#   4.85,
#   4.45,
#   5.35,
#   4.7,
#   6.13,
#   6.93,
#   7.58,
#   6.71,
#   10.65,
#   14.99,
#   4.7,
#   7.27,
#   5.01,
#   6.93,
#   7.87,
#   5.97,
#   2.24,
#   5.82,
#   3.36,
#   6.89,
#   4.7,
#   6.82,
#   10.29,
#   0.27,
#   4.7,
#   9.17,
#   3,
#   8.72,
#   4.94,
#   17.22,
#   3.78,
#   12.75,
#   16.11,
#   15.88,
#   3.24,
#   4.7,
#   4.7,
#   2.24,
#   2.28,
#   9.71,
#   6.2,
#   3.71,
#   14,
#   5.99,
#   2.46,
#   3.69,
#   2.15,
#   13.87,
#   10.29,
#   13.87,
#   14.99,
#   13.87,
#   12.75,
#   3.85,
#   10.45,
#   6.93,
#   2.37,
#   13,
#   23.04,
#   6.93,
#   3.29,
#   3.36,
#   4.7,
#   8.95,
#   5.86,
#   9.17,
#   4.7,
#   9.75,
#   4.29,
#   6.11,
#   5.82,
#   18.1,
#   3.53,
#   7.61,
#   3.58,
#   12.71,
#   6.85,
#   5.82,
#   2.01,
#   8.05,
#   4,
#   14.99,
#   10.02,
#   10.29,
#   18.32,
#   19.46,
#   9.17,
#   8.81,
#   13.87,
#   5.59,
#   5.82,
#   1.19,
#   3.36,
#   13.87,
#   8.16,
#   10.54,
#   4.7,
#   9.17,
#   5.82,
#   4.43,
#   6.93,
#   5.91,
#   13.04,
#   3.53,
#   0.83,
#   17.22,
#   7.45,
#   4.7,
#   3.06,
#   5.86,
#   6.93,
#   5.48,
#   11.01,
#   9.4,
#   6.93,
#   4.83,
#   1.99,
#   17.22,
#   13.67,
#   18.5,
#   3.38,
#   13.62,
#   4.7,
#   4.7,
#   4.29,
#   5.82,
#   2.57,
#   3.36,
#   2.19,
#   8.05,
#   9.51,
#   3.36,
#   1.74,
#   4.29,
#   8.93,
#   12.75,
#   4.32,
#   4.99,
#   4.97,
#   2.24,
#   3.36,
#   1.39,
#   2.13,
#   8.01,
#   6.93,
#   13.87,
#   4.7,
#   13.42,
#   2.24,
#   8.52,
#   3.53,
#   3.36,
#   7.58,
#   9.17,
#   3.36,
#   8.05,
#   17.18,
#   7.96,
#   3.76,
#   12.75,
#   9.17,
#   7.29,
#   6.35,
#   5.82,
#   12.28,
#   4.09,
#   10.8,
#   2.62,
#   4.7,
#   8.3,
#   3.36,
#   3.47,
#   3.36,
#   25.99,
#   8.05,
#   9.66,
#   9.17,
#   13.87,
#   5.73,
#   1.45,
#   5.01,
#   8.95,
#   3.36,
#   9.17,
#   4.68,
#   22.86,
#   4.7,
#   13.27,
#   16.93,
#   5.3,
#   8.05,
#   6.96,
#   18.5,
#   1.01,
#   10.47,
#   4.7,
#   4.83,
#   7.78,
#   3.94,
#   2.42,
#   1.99,
#   22.35,
#   4.81,
#   3.69,
#   19.01,
#   6.96,
#   8.05,
#   6.82,
#   2.59,
#   6.6,
#   9.17,
#   5.57,
#   6.71,
#   14.94,
#   5.82,
#   2.64,
#   4.7,
#   8.05,
#   11.59,
#   2.84,
#   12.75,
#   5.01,
#   3.36,
#   1.57,
#   6.91,
#   2.24,
#   0.78,
#   7.34,
#   7.83,
#   5.48,
#   3.36,
#   2.19,
#   11.18,
#   3.85,
#   9.17,
#   1.92,
#   5.82,
#   4.59,
#   17.83,
#   2.55,
#   2.71,
#   3.22,
#   13.87,
#   13.13,
#   3.36,
#   12.46,
#   4.05,
#   8.95,
#   1.01,
#   6.93,
#   6.71,
#   3.36,
#   4.7,
#   1.61,
#   10.33,
#   2.19,
#   5.77,
#   4.7,
#   2.24,
#   7.27,
#   4.7,
#   5.82,
#   3.27,
#   1.43,
#   4.7,
#   15.57,
#   2.24,
#   2.24,
#   5.82,
#   12.48,
#   9.42,
#   3.15,
#   5.82,
#   12.75,
#   17.38,
#   7.29,
#   9.17,
#   4.7,
#   5.19,
#   6.93,
#   4.54,
#   8.05,
#   4.7,
#   2.91,
#   11.41,
#   6.93,
#   1.99,
#   6.93,
#   6.98,
#   5.97,
#   13.87,
#   3.6,
#   6.93,
#   6.33,
#   0.54,
#   10.29,
#   5.28,
#   9.35,
#   9.17,
#   6.93,
#   9.17,
#   3.53,
#   0.63,
#   5.82,
#   4.7,
#   5.46,
#   5.28,
#   3.36,
#   6.93,
#   8.05,
#   7.94,
#   5.82,
#   4.7,
#   6.91,
#   2.66,
#   7.83,
#   19.46,
#   15.61,
#   8.05,
#   3.33,
#   3.02,
#   8.68,
#   0.69,
#   8.52,
#   8.66,
#   6.93,
#   4.76,
#   6.98,
#   1.03,
#   1.92,
#   10.94,
#   3.56,
#   13.87,
#   7.67,
#   3.78,
#   11.5,
#   2.39,
#   19.46,
#   5.12,
#   11.41,
#   17.22,
#   18.34,
#   3.47,
#   6.64,
#   2.73,
#   10.29,
#   5.01,
#   10.78,
#   9.17,
#   6.93,
#   4.12,
#   5.82,
#   12.75,
#   5.82,
#   3.09,
#   3.36,
#   6.71,
#   3.67,
#   2.55,
#   7.23,
#   3,
#   5.28,
#   7.58,
#   0.98,
#   5.77,
#   23.04,
#   11.41,
#   6.93,
#   6.93,
#   7.58,
#   3.89,
#   5.82,
#   1.45,
#   5.77,
#   4.03,
#   1.12,
#   9.17,
#   5.82,
#   13.04,
#   3.67,
#   2.24,
#   9.73,
#   9.33,
#   2.01,
#   2.93,
#   5.82,
#   6.42,
#   3.6,
#   8.05,
#   10.04,
#   12.75,
#   17.18,
#   1.83,
#   7.94,
#   3.83,
#   3.36,
#   3.36,
#   2.53,
#   5.61,
#   3.36,
#   8.95,
#   22.64,
#   17.47,
#   11.41,
#   2.17,
#   13.09,
#   11.18,
#   5.64,
#   11.99,
#   4.47,
#   2.17,
#   17.22,
#   14.7]}

# %%
#Create City data frame from dictionary created
citydata_df = pd.DataFrame.from_dict(city_dict)
citydata_df
# Out:
#                       City  Cloudiness Country        Date  Humidity    Lat  \
# 0                     hilo           1      US  1595377565        58  19.73
# 1           port elizabeth           0      ZA  1595377565        59 -33.92
# 2                    kutum          64      SD  1595377565        54  14.20
# 3            mount gambier          90      AU  1595377565        93 -37.83
# 4                    sylva          99      RU  1595377565        93  58.03
# ..                     ...         ...     ...         ...       ...    ...
# 585                jiuquan          62      CN  1595377612        25  39.74
# 586             ust-kachka          98      RU  1595377612        93  58.01
# 587                  ravar           0      IR  1595377612        22  31.27
# 588  los llanos de aridane          75      ES  1595377612        69  28.66
# 589               celestun          11      MX  1595377612        72  20.87
#
#         Lng  Max Temp  Wind Speed
# 0   -155.09     84.20       11.41
# 1     25.57     62.60       16.11
# 2     24.67     77.47        6.73
# 3    140.77     48.20        5.82
# 4     56.76     60.80        4.47
# ..      ...       ...         ...
# 585   98.52     78.08       11.99
# 586   55.67     60.80        4.47
# 587   56.81     71.82        2.17
# 588  -17.92     73.40       17.22
# 589  -90.40     83.89       14.70
#
# [590 rows x 9 columns]

# %%
#Output file to CSv
citydata_df.to_csv("output_data_file")

# %%
 citydata_df.count()
# Out:
# City          590
# Cloudiness    590
# Country       590
# Date          590
# Humidity      590
# Lat           590
# Lng           590
# Max Temp      590
# Wind Speed    590
# dtype: int64

# %% [markdown]
# Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# Inspect the data and remove the cities where the humidity > 100%
citydataHumid_df = citydata_df[citydata_df["Humidity"]>100]
citydataHumid_df
# Out:
# Empty DataFrame
# Columns: [City, Cloudiness, Country, Date, Humidity, Lat, Lng, Max Temp, Wind Speed]
# Index: []

# %%
#  Get the indices of cities that have humidity over 100%.
#NONE

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
#none

# %%
# Extract relevant fields from the data frame
#none
# Export the City_Data into a csv

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
#Just a print of the dataframe for reference
citydata_df.head()
# Out:
#              City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0            hilo           1      US  1595377565        58  19.73 -155.09
# 1  port elizabeth           0      ZA  1595377565        59 -33.92   25.57
# 2           kutum          64      SD  1595377565        54  14.20   24.67
# 3   mount gambier          90      AU  1595377565        93 -37.83  140.77
# 4           sylva          99      RU  1595377565        93  58.03   56.76
#
#    Max Temp  Wind Speed
# 0     84.20       11.41
# 1     62.60       16.11
# 2     77.47        6.73
# 3     48.20        5.82
# 4     60.80        4.47

# %%
#Scatter Plot for Latitude Vs. Max Temp
lattitude = citydata_df["Lat"]
maxtemp = citydata_df["Max Temp"]
plt.scatter(lattitude,maxtemp, edgecolor = 'black')
plt.xlabel("Lattitude")
plt.ylabel("Max Temp")
plt.title("City Latitude vs. Max Temp (%s)" % time.strftime("%x"))
plt.grid()
plt.savefig("../LatvsMxTemp.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
#Scatter Plot for Latitude Vs. Humidity
lattitude = citydata_df["Lat"]
maxtemp = citydata_df["Humidity"]
plt.scatter(lattitude,maxtemp, edgecolor = 'black')
plt.xlabel("Lattitude")
plt.ylabel("Humidity")
plt.title("City Latitude vs. Humidity (%s)" % time.strftime("%x"))
plt.grid()
plt.savefig("../LatvsHum.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
#Scatter Plot for Latitude Vs. Cloudiness
lattitude = citydata_df["Lat"]
maxtemp = citydata_df["Cloudiness"]

plt.scatter(lattitude,maxtemp, edgecolor = 'black')
plt.xlabel("Lattitude")
plt.ylabel("Cloudiness")
plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%x"))
plt.grid()
plt.savefig("../Latvscloud.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
#Scatter Plot for Latitude Vs. Wind Speed
lattitude = citydata_df["Lat"]
maxtemp = citydata_df["Wind Speed"]
plt.scatter(lattitude,maxtemp, edgecolor = 'black')
plt.xlabel("Lattitude")
plt.ylabel("Wind Speed")
plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime("%x"))
plt.grid()
plt.savefig("../LatvsWndSpeed.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
# Create Northern and Southern Hemisphere DataFrames
def regline(x_values, y_values, ylabel, coordinate ): 
    (slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    #plt.annotate(line_eq, xy =(-1,50), xycoords='data', xytext=(0, 0.2), textcoords='axes fraction',fontsize=12,color="red")
    plt.annotate(line_eq, coordinate, fontsize=12,color="red")
    plt.xlabel('Latitude')
    plt.ylabel(ylabel)
    print(f"The r-squared is: {rvalue**2}")

# %%
# Create Northern Hemisphere DataFrames
North_df = citydata_df.loc[citydata_df["Lat"]>=0]
North_df.head()
# Out:
#          City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0        hilo           1      US  1595377565        58  19.73 -155.09
# 2       kutum          64      SD  1595377565        54  14.20   24.67
# 4       sylva          99      RU  1595377565        93  58.03   56.76
# 6  rawalpindi          96      PK  1595377274        94  33.60   73.07
# 7     iqaluit          90      CA  1595377340        87  63.75  -68.51
#
#    Max Temp  Wind Speed
# 0     84.20       11.41
# 2     77.47        6.73
# 4     60.80        4.47
# 6     69.80        2.62
# 7     48.20       10.29

# %%
## Create Southern Hemisphere DataFrames
South_df = citydata_df.loc[citydata_df["Lat"]<0]
South_df.head()
# Out:
#               City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 1   port elizabeth           0      ZA  1595377565        59 -33.92   25.57
# 3    mount gambier          90      AU  1595377565        93 -37.83  140.77
# 5        martapura          83      ID  1595377565        94  -3.42  114.85
# 8          rikitea          58      PF  1595377566        60 -23.12 -134.97
# 14    punta arenas           9      CL  1595377565        92 -53.15  -70.92
#
#     Max Temp  Wind Speed
# 1      62.60       16.11
# 3      48.20        5.82
# 5      78.80        2.24
# 8      66.43       17.36
# 14     19.40        4.70

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Northern Hemisphere - Max Temp vs. Latitude Linear Regression
x_values = North_df["Lat"]
y_values = North_df["Max Temp"]
regline(x_values, y_values, "Max Temp", (10,40))
plt.title("North Regression Latitude vs. Max Temp (%s)" % time.strftime("%x"))
plt.savefig("../regNMxTmpLat.png")
plt.show()
# Out:
# The r-squared is: 0.41947843920673383

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Southern Hemisphere - Max Temp vs. Latitude Linear Regression
x_values = South_df["Lat"]
y_values = South_df["Max Temp"]
regline(x_values, y_values, "Max Temp", (-50,20) )
plt.title("South Regression Latitude vs. Max Temp (%s)" % time.strftime("%x"))
plt.savefig("../regSMxTmpLat.png")
plt.show()
# Out:
# The r-squared is: 0.6432433625340559

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression
x_values = North_df["Lat"]
y_values = North_df["Humidity"]
regline(x_values, y_values, "Humidity", (10,40))
plt.title("North Regression Latitude vs. Humidity (%s)" % time.strftime("%x"))
plt.savefig("../regNHumidLat.png")
plt.show()
# Out:
# The r-squared is: 0.017435830442053817

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression
x_values = South_df["Lat"]
y_values = South_df["Humidity"]
regline(x_values, y_values, "Humidity", (-50,20))
plt.title("South Regression Latitude vs. Humidity (%s)" % time.strftime("%x"))
plt.savefig("../regSHumidLat.png")
plt.show()
# Out:
# The r-squared is: 0.0021107291486427843

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression
x_values = North_df["Lat"]
y_values = North_df["Cloudiness"]
regline(x_values, y_values, "Cloudiness", (10,50))
plt.title("North Regression Latitude vs. Cloudiness (%s)" % time.strftime("%x"))
plt.savefig("../regNCloudLat.png")
plt.show()
# Out:
# The r-squared is: 0.008515285984082487

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression
x_values = South_df["Lat"]
y_values = South_df["Cloudiness"]
regline(x_values, y_values, "Cloudiness", (-50,20))
plt.title("South Regression Latitude vs. Cloudiness (%s)" % time.strftime("%x"))
plt.savefig("../regSCloudLat.png")
plt.show()
# Out:
# The r-squared is: 0.034015766990532555

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#Northern Hemisphere - Wind Speed (%) vs. Latitude Linear Regression
x_values = North_df["Lat"]
y_values = North_df["Wind Speed"]
regline(x_values, y_values, "Wind Speed", (0,25))
plt.title("North Regression Latitude vs. Wind Speed (%s)" % time.strftime("%x"))
plt.savefig("../regNWindSpeedLat.png")
plt.show()
# Out:
# The r-squared is: 0.022486607764695108

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#Southern Hemisphere - Wind Speed (%) vs. Latitude Linear Regression
x_values = South_df["Lat"]
y_values = South_df["Wind Speed"]
regline(x_values, y_values, "Wind Speed", (-25,10))
plt.title("South Regression Latitude vs. Wind Speed (%s)" % time.strftime("%x"))
plt.savefig("../regSWindSpeedLat.png")
plt.show()
# Out:
# The r-squared is: 0.01815692990871995
